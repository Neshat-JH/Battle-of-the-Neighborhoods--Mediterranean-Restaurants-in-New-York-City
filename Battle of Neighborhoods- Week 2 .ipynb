# %% [markdown]
# # Introduction
# New York City is a melting pot for cultures and cuisines. You should be able to find any s of cuisines you can imagine in NYC.
# One of the most delicious and diverse cuisines is Persian (Iranian) food. Persian cuisine’s diversity comes from the variety of cultures in Iran. There are endless varieties of dishes and breads; made with ingredients that are native to Iran, such as saffron, pistachios and walnuts.
# When you Google ‘Persian Restaurants in New York’ a good number of them show up. When you check the Category of the restaurant, they are mostly listed as “Mediterranean Cuisine”! Persian and Mediterranean have a lot of common ground but there are many authentic Iranian dishes that are usually not available in most Mediterranean restaurants. However, I believe since the Mediterranean cuisines are more known in America, Persian restaurant businesses label themselves as such so they appear more in searches! Thus, in order to have a wider search in this project I’m going to request and analyze data related to the Mediterranean restaurants.

# %% [markdown]
# ## Business Problem
# This project can be helpful for all the investors looking for great business opportunities in the restaurant industry. Opening a Persian restaurant in general is a great business idea since it has something to offer for every taste! However, in this project I am about to dig deep into New York City’s neighborhoods to find the best location to open a new Persian restaurant. I am also going to find out where we can find the best Mediterranean food in NYC today! Understanding how current businesses are doing in different neighborhoods can lead us to a better decision on where to open a new one.

# %% [markdown]
# ## Data Required and Sources
# In order to tackle the problem statement, we would need a very thorough data on New York City. In addition to NYC Boroughs and Neighborhoods, we would need the latitude and longitude of each area to be able to use visualization maps and achieve a better analysis. We would also need detail of each venue and Mediterranean restaurant, such as the rankings, number of likes and tips given by customers.
#
# Many online sources provide data on different locations around the world. In this project, I am going to use data from http://cocl.us/new_york_dataset to get the data on New York City’s boroughs and neighborhoods. The geographical coordination (latitude and longitude) of each neighborhood can then be accesses through Python package called Geocoder. In addition, Folium can be used to create the visualization maps.
# Foursquare has a large database including different venues information. Here, we are interested in restaurants’ data. Getting access to the Foursquare API we can access information on restaurants in New York City’s different neighborhoods. We can also get access to restaurants rankings, and other details such as number of likes and tips given on Foursquare!
# Putting all the information together we can have a good idea of the number of Mediterranean restaurants in each neighborhood and find the best ranking Mediterranean restaurants in town.  Having all the information discussed in previous sections help the investors decide where is the best location to open a new Mediterranean restaurant. Moreover, by looking at the statistical data on current businesses they can project how successful their business will be in the future!

# %%
#importing libraries and packages that are going to be used.
import numpy as np 
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests 

from bs4 import BeautifulSoup
import os

#installing map rendering library
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 

# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim #converts an address into latitude and longitude values

# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

print('Importing is all DONE!')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Importing is all DONE!

# %% [markdown]
# To be able to use Foursquare I need to provide my variables:

# %%
#I need to define Foursquare Credentials ( Client ID and the Client Secret ID)
#and the Foursquare API version
CLIENT_ID = 'YX50D425ZLUUX5PTQMTKGCTQYWBYN3FYHWUPZ5HNDJBQBFMO' 
CLIENT_SECRET = 'VGY2AL2QATDICUTX13VDVNP0KJGJLJ0APSSS2KRZ4WUCTSUM' 
VERSION = '20180605'

# %%
#defining functions to get latitude and longitue of locations
def geo_location(address):
    geolocator = Nominatim(user_agent="foursquare_persian_agent")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    return latitude,longitude

#setting variables, and providing url to fetch data from foursquare api
def get_venues(lat,lng):
    radius=400
    LIMIT=100
    url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
#requesting data
    results = requests.get(url).json()
    venue_data=results['response']['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

#now doing the same thing but to get venue details such as ratings, tips etc.
def get_venue_details(venue_id):
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    results = requests.get(url).json()
    print(results)
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

def get_new_york_data():
    url='https://cocl.us/new_york_dataset'
    resp=requests.get(url).json()
    features=resp['features']
    column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
    new_york_data = pd.DataFrame(columns=column_names)
    for data in features:
        borough = data['properties']['borough'] 
        neighborhood_name = data['properties']['name']
        neighborhood_latlon = data['geometry']['coordinates']
        neighborhood_lat = neighborhood_latlon[1]
        neighborhood_lon = neighborhood_latlon[0]
        new_york_data = new_york_data.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
    return new_york_data

print("All functions are defined!")
# Out:
# All functions are defined!

# %% [markdown]
# Now that we have imported our libraries and defined our functions and set our requests from Foursquare, it is time to get some data about New York City:

# %%
nyc_data=get_new_york_data()
nyc_data.head(10)
# Out:
#      Borough    Neighborhood   Latitude  Longitude
# 0      Bronx       Wakefield  40.894705 -73.847201
# 1      Bronx      Co-op City  40.874294 -73.829939
# 2      Bronx     Eastchester  40.887556 -73.827806
# 3      Bronx       Fieldston  40.895437 -73.905643
# 4      Bronx       Riverdale  40.890834 -73.912585
# 5      Bronx     Kingsbridge  40.881687 -73.902818
# 6  Manhattan     Marble Hill  40.876551 -73.910660
# 7      Bronx        Woodlawn  40.898273 -73.867315
# 8      Bronx         Norwood  40.877224 -73.879391
# 9      Bronx  Williamsbridge  40.881039 -73.857446

# %% [markdown]
# Seems that each Borough in NYC is consisted of many Neighborhoods. In order to find out how many different Neighborhoods we have in our data we can use the .shape method:

# %%
nyc_data.shape
# Out:
# (306, 4)

# %% [markdown]
# Our data includes 306 different Neighborhoods in NYC.

# %% [markdown]
# Just to get an idea, I'm going to use a bar plot visualization to see how many Neighborhoods are there in each Borough:

# %%
clr = "blue"
nyc_data.groupby('Borough')['Neighborhood'].count().plot.bar(figsize=(8,6), color=clr)
plt.title('Neighborhoods per Borough-NYC', fontsize = 18)
plt.xlabel('Borough', fontsize = 14)
plt.ylabel('Number of Neighborhoods',fontsize = 14)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %% [markdown]
# Some of NYC's Boroughs such as Queens has around 80 different Neighborhoods!

# %% [markdown]
# ## Mediterranean Restaurants in Each Neighborhood
# Now it's time to look into each Borough and Neighborhood to see how many Persian restaurants are out there!Just a quick google search and it's obvious that most of Persian Restaurants have identified themselves as Mediterranean cuisine. Since not many people know about Persian Cuisine, it might be wise for businesses to include themselves in a bigger and much known category. If they tag their restaurant as let's say "Mediterranean" then they will show up in more searches!
# Thus, I'm going to set the Category as 'Mediterranean Restuarant' to catch all possible Persian restuarants in NYC:

# %%
#queens has most neighborhoods
#prepare neighborhood list that contains persian restaurants
column_names=['Borough', 'Neighborhood', 'ID','Name']
persian_rest_nyc=pd.DataFrame(columns=column_names)
count=1
for row in nyc_data.values.tolist():
    Borough, Neighborhood, Latitude, Longitude=row
    venues = get_venues(Latitude,Longitude)
    persian_restaurants=venues[venues['Category']=='Mediterranean Restaurant']   
    print('(',count,'/',len(nyc_data),')','Persian Restaurants in '+Neighborhood+', '+Borough+':'+str(len(persian_restaurants)))
    print(row)
    for resturant_detail in persian_restaurants.values.tolist():
        id, name , category=resturant_detail
        persian_rest_nyc = persian_rest_nyc.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name
                                               }, ignore_index=True)
    count+=1
# Out:
# ( 1 / 306 ) Persian Restaurants in Wakefield, Bronx:0
# ['Bronx', 'Wakefield', 40.89470517661, -73.84720052054902]
# ( 2 / 306 ) Persian Restaurants in Co-op City, Bronx:0
# ['Bronx', 'Co-op City', 40.87429419303012, -73.82993910812398]
# ( 3 / 306 ) Persian Restaurants in Eastchester, Bronx:0
# ['Bronx', 'Eastchester', 40.887555677350775, -73.82780644716412]
# ( 4 / 306 ) Persian Restaurants in Fieldston, Bronx:0
# ['Bronx', 'Fieldston', 40.89543742690383, -73.90564259591682]
# ( 5 / 306 ) Persian Restaurants in Riverdale, Bronx:0
# ['Bronx', 'Riverdale', 40.890834493891305, -73.9125854610857]
# ( 6 / 306 ) Persian Restaurants in Kingsbridge, Bronx:0
# ['Bronx', 'Kingsbridge', 40.88168737120521, -73.90281798724604]
# ( 7 / 306 ) Persian Restaurants in Marble Hill, Manhattan:0
# ['Manhattan', 'Marble Hill', 40.87655077879964, -73.91065965862981]
# ( 8 / 306 ) Persian Restaurants in Woodlawn, Bronx:0
# ['Bronx', 'Woodlawn', 40.89827261213805, -73.86731496814176]
# ( 9 / 306 ) Persian Restaurants in Norwood, Bronx:0
# ['Bronx', 'Norwood', 40.87722415599446, -73.8793907395681]
# ( 10 / 306 ) Persian Restaurants in Williamsbridge, Bronx:0
# ['Bronx', 'Williamsbridge', 40.88103887819211, -73.85744642974207]
# ( 11 / 306 ) Persian Restaurants in Baychester, Bronx:0
# ['Bronx', 'Baychester', 40.866858107252696, -73.83579759808117]
# ( 12 / 306 ) Persian Restaurants in Pelham Parkway, Bronx:0
# ['Bronx', 'Pelham Parkway', 40.85741349808865, -73.85475564017999]
# ( 13 / 306 ) Persian Restaurants in City Island, Bronx:0
# ['Bronx', 'City Island', 40.84724670491813, -73.78648845267413]
# ( 14 / 306 ) Persian Restaurants in Bedford Park, Bronx:0
# ['Bronx', 'Bedford Park', 40.870185164975325, -73.8855121841913]
# ( 15 / 306 ) Persian Restaurants in University Heights, Bronx:0
# ['Bronx', 'University Heights', 40.85572707719664, -73.9104159619131]
# ( 16 / 306 ) Persian Restaurants in Morris Heights, Bronx:0
# ['Bronx', 'Morris Heights', 40.84789792606271, -73.91967159119565]
# ( 17 / 306 ) Persian Restaurants in Fordham, Bronx:0
# ['Bronx', 'Fordham', 40.86099679638654, -73.89642655981623]
# ( 18 / 306 ) Persian Restaurants in East Tremont, Bronx:0
# ['Bronx', 'East Tremont', 40.84269615786053, -73.88735617532338]
# ( 19 / 306 ) Persian Restaurants in West Farms, Bronx:0
# ['Bronx', 'West Farms', 40.83947505672653, -73.87774474910545]
# ( 20 / 306 ) Persian Restaurants in High  Bridge, Bronx:0
# ['Bronx', 'High  Bridge', 40.836623010706056, -73.9261020935813]
# ( 21 / 306 ) Persian Restaurants in Melrose, Bronx:0
# ['Bronx', 'Melrose', 40.819754370594936, -73.90942160757436]
# ( 22 / 306 ) Persian Restaurants in Mott Haven, Bronx:0
# ['Bronx', 'Mott Haven', 40.80623874935177, -73.91609987487575]
# ( 23 / 306 ) Persian Restaurants in Port Morris, Bronx:0
# ['Bronx', 'Port Morris', 40.801663627756206, -73.91322139386135]
# ( 24 / 306 ) Persian Restaurants in Longwood, Bronx:0
# ['Bronx', 'Longwood', 40.81509904545822, -73.8957882009446]
# ( 25 / 306 ) Persian Restaurants in Hunts Point, Bronx:0
# ['Bronx', 'Hunts Point', 40.80972987938709, -73.88331505955291]
# ( 26 / 306 ) Persian Restaurants in Morrisania, Bronx:0
# ['Bronx', 'Morrisania', 40.82359198585534, -73.90150648943059]
# ( 27 / 306 ) Persian Restaurants in Soundview, Bronx:0
# ['Bronx', 'Soundview', 40.821012197914015, -73.86574609554924]
# ( 28 / 306 ) Persian Restaurants in Clason Point, Bronx:0
# ['Bronx', 'Clason Point', 40.80655112003589, -73.85414416189266]
# ( 29 / 306 ) Persian Restaurants in Throgs Neck, Bronx:0
# ['Bronx', 'Throgs Neck', 40.81510925804005, -73.81635002158441]
# ( 30 / 306 ) Persian Restaurants in Country Club, Bronx:0
# ['Bronx', 'Country Club', 40.844245936947374, -73.8240992675385]
# ( 31 / 306 ) Persian Restaurants in Parkchester, Bronx:0
# ['Bronx', 'Parkchester', 40.837937822267286, -73.85600310535783]
# ( 32 / 306 ) Persian Restaurants in Westchester Square, Bronx:0
# ['Bronx', 'Westchester Square', 40.8406194964327, -73.84219407604444]
# ( 33 / 306 ) Persian Restaurants in Van Nest, Bronx:0
# ['Bronx', 'Van Nest', 40.84360847124718, -73.8662991807561]
# ( 34 / 306 ) Persian Restaurants in Morris Park, Bronx:0
# ['Bronx', 'Morris Park', 40.847549063536334, -73.85040178030421]
# ( 35 / 306 ) Persian Restaurants in Belmont, Bronx:0
# ['Bronx', 'Belmont', 40.85727710073895, -73.88845196134804]
# ( 36 / 306 ) Persian Restaurants in Spuyten Duyvil, Bronx:0
# ['Bronx', 'Spuyten Duyvil', 40.88139497727086, -73.91719048210393]
# ( 37 / 306 ) Persian Restaurants in North Riverdale, Bronx:0
# ['Bronx', 'North Riverdale', 40.90854282950666, -73.90453054908927]
# ( 38 / 306 ) Persian Restaurants in Pelham Bay, Bronx:0
# ['Bronx', 'Pelham Bay', 40.85064140940335, -73.8320737824047]
# ( 39 / 306 ) Persian Restaurants in Schuylerville, Bronx:0
# ['Bronx', 'Schuylerville', 40.82657951686922, -73.82620275994073]
# ( 40 / 306 ) Persian Restaurants in Edgewater Park, Bronx:0
# ['Bronx', 'Edgewater Park', 40.821986118163494, -73.81388514428619]
# ( 41 / 306 ) Persian Restaurants in Castle Hill, Bronx:0
# ['Bronx', 'Castle Hill', 40.819014376988314, -73.84802729582735]
# ( 42 / 306 ) Persian Restaurants in Olinville, Bronx:0
# ['Bronx', 'Olinville', 40.87137078192371, -73.86332361652777]
# ( 43 / 306 ) Persian Restaurants in Pelham Gardens, Bronx:0
# ['Bronx', 'Pelham Gardens', 40.86296562477998, -73.84161194831223]
# ( 44 / 306 ) Persian Restaurants in Concourse, Bronx:0
# ['Bronx', 'Concourse', 40.83428380733851, -73.91558941773444]
# ( 45 / 306 ) Persian Restaurants in Unionport, Bronx:0
# ['Bronx', 'Unionport', 40.82977429787161, -73.85053524451935]
# ( 46 / 306 ) Persian Restaurants in Edenwald, Bronx:0
# ['Bronx', 'Edenwald', 40.88456130303732, -73.84808271877168]
# ( 47 / 306 ) Persian Restaurants in Bay Ridge, Brooklyn:0
# ['Brooklyn', 'Bay Ridge', 40.625801065010656, -74.03062069353813]
# ( 48 / 306 ) Persian Restaurants in Bensonhurst, Brooklyn:0
# ['Brooklyn', 'Bensonhurst', 40.61100890202044, -73.99517998380729]
# ( 49 / 306 ) Persian Restaurants in Sunset Park, Brooklyn:0
# ['Brooklyn', 'Sunset Park', 40.64510294925429, -74.01031618527784]
# ( 50 / 306 ) Persian Restaurants in Greenpoint, Brooklyn:0
# ['Brooklyn', 'Greenpoint', 40.7302009848647, -73.95424093127393]
# ( 51 / 306 ) Persian Restaurants in Gravesend, Brooklyn:0
# ['Brooklyn', 'Gravesend', 40.59526001306593, -73.97347087708445]
# ( 52 / 306 ) Persian Restaurants in Brighton Beach, Brooklyn:1
# ['Brooklyn', 'Brighton Beach', 40.57682506566604, -73.96509448785336]
# ( 53 / 306 ) Persian Restaurants in Sheepshead Bay, Brooklyn:0
# ['Brooklyn', 'Sheepshead Bay', 40.58689012678384, -73.94318640482979]
# ( 54 / 306 ) Persian Restaurants in Manhattan Terrace, Brooklyn:0
# ['Brooklyn', 'Manhattan Terrace', 40.61443251335098, -73.95743840559939]
# ( 55 / 306 ) Persian Restaurants in Flatbush, Brooklyn:0
# ['Brooklyn', 'Flatbush', 40.63632589026677, -73.95840106533903]
# ( 56 / 306 ) Persian Restaurants in Crown Heights, Brooklyn:0
# ['Brooklyn', 'Crown Heights', 40.67082917695294, -73.94329119073582]
# ( 57 / 306 ) Persian Restaurants in East Flatbush, Brooklyn:0
# ['Brooklyn', 'East Flatbush', 40.64171776668961, -73.93610256185836]
# ( 58 / 306 ) Persian Restaurants in Kensington, Brooklyn:0
# ['Brooklyn', 'Kensington', 40.642381958003526, -73.98042110559474]
# ( 59 / 306 ) Persian Restaurants in Windsor Terrace, Brooklyn:0
# ['Brooklyn', 'Windsor Terrace', 40.65694583575104, -73.98007340430172]
# ( 60 / 306 ) Persian Restaurants in Prospect Heights, Brooklyn:0
# ['Brooklyn', 'Prospect Heights', 40.676822262254724, -73.9648592426269]
# ( 61 / 306 ) Persian Restaurants in Brownsville, Brooklyn:0
# ['Brooklyn', 'Brownsville', 40.66394994339755, -73.91023536176607]
# ( 62 / 306 ) Persian Restaurants in Williamsburg, Brooklyn:0
# ['Brooklyn', 'Williamsburg', 40.70714439344251, -73.95811529220927]
# ( 63 / 306 ) Persian Restaurants in Bushwick, Brooklyn:1
# ['Brooklyn', 'Bushwick', 40.69811611017901, -73.92525797487045]
# ( 64 / 306 ) Persian Restaurants in Bedford Stuyvesant, Brooklyn:0
# ['Brooklyn', 'Bedford Stuyvesant', 40.687231607720456, -73.94178488690297]
# ( 65 / 306 ) Persian Restaurants in Brooklyn Heights, Brooklyn:0
# ['Brooklyn', 'Brooklyn Heights', 40.695863722724084, -73.99378225496424]
# ( 66 / 306 ) Persian Restaurants in Cobble Hill, Brooklyn:0
# ['Brooklyn', 'Cobble Hill', 40.687919722485574, -73.99856139218463]
# ( 67 / 306 ) Persian Restaurants in Carroll Gardens, Brooklyn:0
# ['Brooklyn', 'Carroll Gardens', 40.680540231076485, -73.99465372828006]
# ( 68 / 306 ) Persian Restaurants in Red Hook, Brooklyn:0
# ['Brooklyn', 'Red Hook', 40.676253230250886, -74.0127589747356]
# ( 69 / 306 ) Persian Restaurants in Gowanus, Brooklyn:0
# ['Brooklyn', 'Gowanus', 40.673931143187154, -73.99444087145339]
# ( 70 / 306 ) Persian Restaurants in Fort Greene, Brooklyn:0
# ['Brooklyn', 'Fort Greene', 40.68852726018977, -73.97290574369092]
# ( 71 / 306 ) Persian Restaurants in Park Slope, Brooklyn:0
# ['Brooklyn', 'Park Slope', 40.67232052268197, -73.97705030183924]
# ( 72 / 306 ) Persian Restaurants in Cypress Hills, Brooklyn:0
# ['Brooklyn', 'Cypress Hills', 40.68239101144211, -73.87661596457296]
# ( 73 / 306 ) Persian Restaurants in East New York, Brooklyn:0
# ['Brooklyn', 'East New York', 40.669925700847045, -73.88069863917366]
# ( 74 / 306 ) Persian Restaurants in Starrett City, Brooklyn:0
# ['Brooklyn', 'Starrett City', 40.64758905230874, -73.87936970045875]
# ( 75 / 306 ) Persian Restaurants in Canarsie, Brooklyn:0
# ['Brooklyn', 'Canarsie', 40.63556432797428, -73.90209269778966]
# ( 76 / 306 ) Persian Restaurants in Flatlands, Brooklyn:0
# ['Brooklyn', 'Flatlands', 40.630446043757466, -73.92911302644674]
# ( 77 / 306 ) Persian Restaurants in Mill Island, Brooklyn:0
# ['Brooklyn', 'Mill Island', 40.606336421685626, -73.90818571777423]
# ( 78 / 306 ) Persian Restaurants in Manhattan Beach, Brooklyn:0
# ['Brooklyn', 'Manhattan Beach', 40.57791350308657, -73.94353722891886]
# ( 79 / 306 ) Persian Restaurants in Coney Island, Brooklyn:0
# ['Brooklyn', 'Coney Island', 40.57429256471601, -73.98868295821637]
# ( 80 / 306 ) Persian Restaurants in Bath Beach, Brooklyn:0
# ['Brooklyn', 'Bath Beach', 40.59951870282238, -73.99875221443519]
# ( 81 / 306 ) Persian Restaurants in Borough Park, Brooklyn:0
# ['Brooklyn', 'Borough Park', 40.633130512758015, -73.99049823044811]
# ( 82 / 306 ) Persian Restaurants in Dyker Heights, Brooklyn:0
# ['Brooklyn', 'Dyker Heights', 40.619219457722636, -74.01931375636022]
# ( 83 / 306 ) Persian Restaurants in Gerritsen Beach, Brooklyn:0
# ['Brooklyn', 'Gerritsen Beach', 40.590848433902046, -73.93010170691196]
# ( 84 / 306 ) Persian Restaurants in Marine Park, Brooklyn:0
# ['Brooklyn', 'Marine Park', 40.609747779894604, -73.93134404108497]
# ( 85 / 306 ) Persian Restaurants in Clinton Hill, Brooklyn:0
# ['Brooklyn', 'Clinton Hill', 40.693229421881504, -73.96784306216367]
# ( 86 / 306 ) Persian Restaurants in Sea Gate, Brooklyn:0
# ['Brooklyn', 'Sea Gate', 40.57637537890224, -74.0078731120024]
# ( 87 / 306 ) Persian Restaurants in Downtown, Brooklyn:0
# ['Brooklyn', 'Downtown', 40.69084402109802, -73.98346337431099]
# ( 88 / 306 ) Persian Restaurants in Boerum Hill, Brooklyn:0
# ['Brooklyn', 'Boerum Hill', 40.685682912091444, -73.98374824115798]
# ( 89 / 306 ) Persian Restaurants in Prospect Lefferts Gardens, Brooklyn:0
# ['Brooklyn', 'Prospect Lefferts Gardens', 40.658420017469815, -73.95489867077713]
# ( 90 / 306 ) Persian Restaurants in Ocean Hill, Brooklyn:0
# ['Brooklyn', 'Ocean Hill', 40.678402554795355, -73.91306831787395]
# ( 91 / 306 ) Persian Restaurants in City Line, Brooklyn:0
# ['Brooklyn', 'City Line', 40.67856995727479, -73.86797598081334]
# ( 92 / 306 ) Persian Restaurants in Bergen Beach, Brooklyn:0
# ['Brooklyn', 'Bergen Beach', 40.61514955045308, -73.89855633630317]
# ( 93 / 306 ) Persian Restaurants in Midwood, Brooklyn:0
# ['Brooklyn', 'Midwood', 40.62559589869843, -73.95759523489838]
# ( 94 / 306 ) Persian Restaurants in Prospect Park South, Brooklyn:0
# ['Brooklyn', 'Prospect Park South', 40.647008603185185, -73.96261316716048]
# ( 95 / 306 ) Persian Restaurants in Georgetown, Brooklyn:0
# ['Brooklyn', 'Georgetown', 40.62384524478419, -73.91607483951324]
# ( 96 / 306 ) Persian Restaurants in East Williamsburg, Brooklyn:1
# ['Brooklyn', 'East Williamsburg', 40.70849241041548, -73.93885815269195]
# ( 97 / 306 ) Persian Restaurants in North Side, Brooklyn:1
# ['Brooklyn', 'North Side', 40.714822906532014, -73.95880857587582]
# ( 98 / 306 ) Persian Restaurants in South Side, Brooklyn:1
# ['Brooklyn', 'South Side', 40.71086147265064, -73.95800095153331]
# ( 99 / 306 ) Persian Restaurants in Ocean Parkway, Brooklyn:0
# ['Brooklyn', 'Ocean Parkway', 40.61305976667942, -73.96836678035541]
# ( 100 / 306 ) Persian Restaurants in Fort Hamilton, Brooklyn:0
# ['Brooklyn', 'Fort Hamilton', 40.61476812694226, -74.03197914537984]
# ( 101 / 306 ) Persian Restaurants in Chinatown, Manhattan:0
# ['Manhattan', 'Chinatown', 40.71561842231432, -73.99427936255978]
# ( 102 / 306 ) Persian Restaurants in Washington Heights, Manhattan:0
# ['Manhattan', 'Washington Heights', 40.85190252555305, -73.93690027985234]
# ( 103 / 306 ) Persian Restaurants in Inwood, Manhattan:0
# ['Manhattan', 'Inwood', 40.86768396449915, -73.92121042203897]
# ( 104 / 306 ) Persian Restaurants in Hamilton Heights, Manhattan:1
# ['Manhattan', 'Hamilton Heights', 40.823604284811935, -73.94968791883366]
# ( 105 / 306 ) Persian Restaurants in Manhattanville, Manhattan:0
# ['Manhattan', 'Manhattanville', 40.8169344294978, -73.9573853935188]
# ( 106 / 306 ) Persian Restaurants in Central Harlem, Manhattan:0
# ['Manhattan', 'Central Harlem', 40.81597606742414, -73.94321112603905]
# ( 107 / 306 ) Persian Restaurants in East Harlem, Manhattan:0
# ['Manhattan', 'East Harlem', 40.79224946663033, -73.94418223148524]
# ( 108 / 306 ) Persian Restaurants in Upper East Side, Manhattan:1
# ['Manhattan', 'Upper East Side', 40.775638573301805, -73.96050763135]
# ( 109 / 306 ) Persian Restaurants in Yorkville, Manhattan:0
# ['Manhattan', 'Yorkville', 40.775929849884875, -73.94711784471826]
# ( 110 / 306 ) Persian Restaurants in Lenox Hill, Manhattan:0
# ['Manhattan', 'Lenox Hill', 40.76811265828733, -73.9588596881376]
# ( 111 / 306 ) Persian Restaurants in Roosevelt Island, Manhattan:0
# ['Manhattan', 'Roosevelt Island', 40.76215960576283, -73.94916769227953]
# ( 112 / 306 ) Persian Restaurants in Upper West Side, Manhattan:1
# ['Manhattan', 'Upper West Side', 40.787657998534854, -73.97705923630603]
# ( 113 / 306 ) Persian Restaurants in Lincoln Square, Manhattan:1
# ['Manhattan', 'Lincoln Square', 40.77352888942166, -73.98533777001262]
# ( 114 / 306 ) Persian Restaurants in Clinton, Manhattan:2
# ['Manhattan', 'Clinton', 40.75910089146212, -73.99611936309479]
# ( 115 / 306 ) Persian Restaurants in Midtown, Manhattan:1
# ['Manhattan', 'Midtown', 40.75469110270623, -73.98166882730304]
# ( 116 / 306 ) Persian Restaurants in Murray Hill, Manhattan:1
# ['Manhattan', 'Murray Hill', 40.748303077252174, -73.97833207924127]
# ( 117 / 306 ) Persian Restaurants in Chelsea, Manhattan:0
# ['Manhattan', 'Chelsea', 40.744034706747975, -74.00311633472813]
# ( 118 / 306 ) Persian Restaurants in Greenwich Village, Manhattan:1
# ['Manhattan', 'Greenwich Village', 40.72693288536128, -73.99991402945902]
# ( 119 / 306 ) Persian Restaurants in East Village, Manhattan:0
# ['Manhattan', 'East Village', 40.727846777270244, -73.98222616506416]
# ( 120 / 306 ) Persian Restaurants in Lower East Side, Manhattan:1
# ['Manhattan', 'Lower East Side', 40.71780674892765, -73.98089031999291]
# ( 121 / 306 ) Persian Restaurants in Tribeca, Manhattan:0
# ['Manhattan', 'Tribeca', 40.721521967443216, -74.01068328559087]
# ( 122 / 306 ) Persian Restaurants in Little Italy, Manhattan:2
# ['Manhattan', 'Little Italy', 40.71932379395907, -73.99730467208073]
# ( 123 / 306 ) Persian Restaurants in Soho, Manhattan:4
# ['Manhattan', 'Soho', 40.72218384131794, -74.00065666959759]
# ( 124 / 306 ) Persian Restaurants in West Village, Manhattan:1
# ['Manhattan', 'West Village', 40.73443393572434, -74.00617998126812]
# ( 125 / 306 ) Persian Restaurants in Manhattan Valley, Manhattan:0
# ['Manhattan', 'Manhattan Valley', 40.797307041702865, -73.96428617740655]
# ( 126 / 306 ) Persian Restaurants in Morningside Heights, Manhattan:1
# ['Manhattan', 'Morningside Heights', 40.807999738165826, -73.96389627905332]
# ( 127 / 306 ) Persian Restaurants in Gramercy, Manhattan:0
# ['Manhattan', 'Gramercy', 40.737209832715, -73.98137594833541]
# ( 128 / 306 ) Persian Restaurants in Battery Park City, Manhattan:1
# ['Manhattan', 'Battery Park City', 40.71193198394565, -74.01686930508617]
# ( 129 / 306 ) Persian Restaurants in Financial District, Manhattan:2
# ['Manhattan', 'Financial District', 40.70710710727048, -74.0106654452127]
# ( 130 / 306 ) Persian Restaurants in Astoria, Queens:1
# ['Queens', 'Astoria', 40.76850859335492, -73.91565374304234]
# ( 131 / 306 ) Persian Restaurants in Woodside, Queens:0
# ['Queens', 'Woodside', 40.74634908860222, -73.90184166838284]
# ( 132 / 306 ) Persian Restaurants in Jackson Heights, Queens:0
# ['Queens', 'Jackson Heights', 40.75198138007367, -73.88282109164365]
# ( 133 / 306 ) Persian Restaurants in Elmhurst, Queens:0
# ['Queens', 'Elmhurst', 40.744048505122024, -73.88165622288388]
# ( 134 / 306 ) Persian Restaurants in Howard Beach, Queens:0
# ['Queens', 'Howard Beach', 40.65422527738487, -73.8381376460028]
# ( 135 / 306 ) Persian Restaurants in Corona, Queens:0
# ['Queens', 'Corona', 40.74238175015667, -73.85682497345258]
# ( 136 / 306 ) Persian Restaurants in Forest Hills, Queens:0
# ['Queens', 'Forest Hills', 40.72526378216503, -73.84447500788983]
# ( 137 / 306 ) Persian Restaurants in Kew Gardens, Queens:0
# ['Queens', 'Kew Gardens', 40.7051790354148, -73.82981905825703]
# ( 138 / 306 ) Persian Restaurants in Richmond Hill, Queens:0
# ['Queens', 'Richmond Hill', 40.69794731471763, -73.83183321446887]
# ( 139 / 306 ) Persian Restaurants in Flushing, Queens:0
# ['Queens', 'Flushing', 40.76445419697846, -73.83177300329582]
# ( 140 / 306 ) Persian Restaurants in Long Island City, Queens:1
# ['Queens', 'Long Island City', 40.75021734610528, -73.93920223915505]
# ( 141 / 306 ) Persian Restaurants in Sunnyside, Queens:0
# ['Queens', 'Sunnyside', 40.74017628351924, -73.92691617561577]
# ( 142 / 306 ) Persian Restaurants in East Elmhurst, Queens:0
# ['Queens', 'East Elmhurst', 40.76407323883091, -73.86704147658772]
# ( 143 / 306 ) Persian Restaurants in Maspeth, Queens:0
# ['Queens', 'Maspeth', 40.725427374093606, -73.89621713626859]
# ( 144 / 306 ) Persian Restaurants in Ridgewood, Queens:0
# ['Queens', 'Ridgewood', 40.70832315613858, -73.90143517559589]
# ( 145 / 306 ) Persian Restaurants in Glendale, Queens:0
# ['Queens', 'Glendale', 40.70276242967838, -73.87074167435605]
# ( 146 / 306 ) Persian Restaurants in Rego Park, Queens:0
# ['Queens', 'Rego Park', 40.72897409480735, -73.8578268690537]
# ( 147 / 306 ) Persian Restaurants in Woodhaven, Queens:0
# ['Queens', 'Woodhaven', 40.68988687915789, -73.8581104655432]
# ( 148 / 306 ) Persian Restaurants in Ozone Park, Queens:0
# ['Queens', 'Ozone Park', 40.680708468265415, -73.84320266173447]
# ( 149 / 306 ) Persian Restaurants in South Ozone Park, Queens:0
# ['Queens', 'South Ozone Park', 40.66854957767195, -73.80986478649041]
# ( 150 / 306 ) Persian Restaurants in College Point, Queens:0
# ['Queens', 'College Point', 40.784902749260205, -73.84304528896125]
# ( 151 / 306 ) Persian Restaurants in Whitestone, Queens:0
# ['Queens', 'Whitestone', 40.78129076602694, -73.81420216610863]
# ( 152 / 306 ) Persian Restaurants in Bayside, Queens:2
# ['Queens', 'Bayside', 40.76604063281064, -73.7742736306867]
# ( 153 / 306 ) Persian Restaurants in Auburndale, Queens:0
# ['Queens', 'Auburndale', 40.76172954903262, -73.79176243728061]
# ( 154 / 306 ) Persian Restaurants in Little Neck, Queens:0
# ['Queens', 'Little Neck', 40.7708261928267, -73.7388977558074]
# ( 155 / 306 ) Persian Restaurants in Douglaston, Queens:0
# ['Queens', 'Douglaston', 40.76684609790763, -73.7424982072733]
# ( 156 / 306 ) Persian Restaurants in Glen Oaks, Queens:0
# ['Queens', 'Glen Oaks', 40.74944079974332, -73.71548118999145]
# ( 157 / 306 ) Persian Restaurants in Bellerose, Queens:0
# ['Queens', 'Bellerose', 40.72857318176675, -73.72012814826903]
# ( 158 / 306 ) Persian Restaurants in Kew Gardens Hills, Queens:0
# ['Queens', 'Kew Gardens Hills', 40.722578244228046, -73.82087764933566]
# ( 159 / 306 ) Persian Restaurants in Fresh Meadows, Queens:0
# ['Queens', 'Fresh Meadows', 40.7343944653313, -73.78271337003264]
# ( 160 / 306 ) Persian Restaurants in Briarwood, Queens:0
# ['Queens', 'Briarwood', 40.71093547252271, -73.81174822458634]
# ( 161 / 306 ) Persian Restaurants in Jamaica Center, Queens:0
# ['Queens', 'Jamaica Center', 40.70465736068717, -73.79690165888289]
# ( 162 / 306 ) Persian Restaurants in Oakland Gardens, Queens:0
# ['Queens', 'Oakland Gardens', 40.74561857141855, -73.75494976234332]
# ( 163 / 306 ) Persian Restaurants in Queens Village, Queens:0
# ['Queens', 'Queens Village', 40.718893092167356, -73.73871484578424]
# ( 164 / 306 ) Persian Restaurants in Hollis, Queens:0
# ['Queens', 'Hollis', 40.71124344191904, -73.75925009335594]
# ( 165 / 306 ) Persian Restaurants in South Jamaica, Queens:0
# ['Queens', 'South Jamaica', 40.696911253789885, -73.7904261313554]
# ( 166 / 306 ) Persian Restaurants in St. Albans, Queens:0
# ['Queens', 'St. Albans', 40.69444538522359, -73.75867603727717]
# ( 167 / 306 ) Persian Restaurants in Rochdale, Queens:0
# ['Queens', 'Rochdale', 40.67521139591733, -73.77258787620906]
# ( 168 / 306 ) Persian Restaurants in Springfield Gardens, Queens:0
# ['Queens', 'Springfield Gardens', 40.666230490368584, -73.76042092682287]
# ( 169 / 306 ) Persian Restaurants in Cambria Heights, Queens:0
# ['Queens', 'Cambria Heights', 40.692774639160845, -73.73526873708026]
# ( 170 / 306 ) Persian Restaurants in Rosedale, Queens:0
# ['Queens', 'Rosedale', 40.659816433428084, -73.73526079428278]
# ( 171 / 306 ) Persian Restaurants in Far Rockaway, Queens:0
# ['Queens', 'Far Rockaway', 40.603134432500894, -73.75497968043872]
# ( 172 / 306 ) Persian Restaurants in Broad Channel, Queens:0
# ['Queens', 'Broad Channel', 40.60302658351238, -73.8200548911032]
# ( 173 / 306 ) Persian Restaurants in Breezy Point, Queens:0
# ['Queens', 'Breezy Point', 40.55740128845452, -73.92551196994168]
# ( 174 / 306 ) Persian Restaurants in Steinway, Queens:0
# ['Queens', 'Steinway', 40.775923015642896, -73.90228960391673]
# ( 175 / 306 ) Persian Restaurants in Beechhurst, Queens:0
# ['Queens', 'Beechhurst', 40.79278140360048, -73.80436451720988]
# ( 176 / 306 ) Persian Restaurants in Bay Terrace, Queens:0
# ['Queens', 'Bay Terrace', 40.782842806245554, -73.7768022262158]
# ( 177 / 306 ) Persian Restaurants in Edgemere, Queens:0
# ['Queens', 'Edgemere', 40.595641807368494, -73.77613282391705]
# ( 178 / 306 ) Persian Restaurants in Arverne, Queens:0
# ['Queens', 'Arverne', 40.58914394372971, -73.79199233136943]
# ( 179 / 306 ) Persian Restaurants in Rockaway Beach, Queens:0
# ['Queens', 'Rockaway Beach', 40.582801696845586, -73.82236121088751]
# ( 180 / 306 ) Persian Restaurants in Neponsit, Queens:0
# ['Queens', 'Neponsit', 40.572036730217015, -73.85754672410827]
# ( 181 / 306 ) Persian Restaurants in Murray Hill, Queens:0
# ['Queens', 'Murray Hill', 40.764126122614066, -73.81276269135866]
# ( 182 / 306 ) Persian Restaurants in Floral Park, Queens:0
# ['Queens', 'Floral Park', 40.741378421945434, -73.70884705889246]
# ( 183 / 306 ) Persian Restaurants in Holliswood, Queens:0
# ['Queens', 'Holliswood', 40.7209572076444, -73.76714166714729]
# ( 184 / 306 ) Persian Restaurants in Jamaica Estates, Queens:0
# ['Queens', 'Jamaica Estates', 40.71680483014613, -73.7872269693666]
# ( 185 / 306 ) Persian Restaurants in Queensboro Hill, Queens:0
# ['Queens', 'Queensboro Hill', 40.7445723092867, -73.82580915110559]
# ( 186 / 306 ) Persian Restaurants in Hillcrest, Queens:0
# ['Queens', 'Hillcrest', 40.723824901829204, -73.79760300912672]
# ( 187 / 306 ) Persian Restaurants in Ravenswood, Queens:0
# ['Queens', 'Ravenswood', 40.761704526054146, -73.93157506072878]
# ( 188 / 306 ) Persian Restaurants in Lindenwood, Queens:0
# ['Queens', 'Lindenwood', 40.66391841925139, -73.84963782402441]
# ( 189 / 306 ) Persian Restaurants in Laurelton, Queens:0
# ['Queens', 'Laurelton', 40.66788389660247, -73.74025607989822]
# ( 190 / 306 ) Persian Restaurants in Lefrak City, Queens:0
# ['Queens', 'Lefrak City', 40.736074570830795, -73.8625247141374]
# ( 191 / 306 ) Persian Restaurants in Belle Harbor, Queens:0
# ['Queens', 'Belle Harbor', 40.57615556543109, -73.8540175039252]
# ( 192 / 306 ) Persian Restaurants in Rockaway Park, Queens:1
# ['Queens', 'Rockaway Park', 40.58034295646131, -73.84153370226186]
# ( 193 / 306 ) Persian Restaurants in Somerville, Queens:0
# ['Queens', 'Somerville', 40.59771061565768, -73.79664750844047]
# ( 194 / 306 ) Persian Restaurants in Brookville, Queens:0
# ['Queens', 'Brookville', 40.66000322733613, -73.75175310731153]
# ( 195 / 306 ) Persian Restaurants in Bellaire, Queens:0
# ['Queens', 'Bellaire', 40.73301404027834, -73.73889198912481]
# ( 196 / 306 ) Persian Restaurants in North Corona, Queens:0
# ['Queens', 'North Corona', 40.7540709990489, -73.85751790676447]
# ( 197 / 306 ) Persian Restaurants in Forest Hills Gardens, Queens:0
# ['Queens', 'Forest Hills Gardens', 40.7146110815117, -73.8410221123401]
# ( 198 / 306 ) Persian Restaurants in St. George, Staten Island:0
# ['Staten Island', 'St. George', 40.6449815710044, -74.07935312512797]
# ( 199 / 306 ) Persian Restaurants in New Brighton, Staten Island:0
# ['Staten Island', 'New Brighton', 40.64061455913511, -74.08701650516625]
# ( 200 / 306 ) Persian Restaurants in Stapleton, Staten Island:0
# ['Staten Island', 'Stapleton', 40.62692762538176, -74.07790192660066]
# ( 201 / 306 ) Persian Restaurants in Rosebank, Staten Island:0
# ['Staten Island', 'Rosebank', 40.61530494652761, -74.06980526716141]
# ( 202 / 306 ) Persian Restaurants in West Brighton, Staten Island:0
# ['Staten Island', 'West Brighton', 40.63187892654607, -74.1071817826561]
# ( 203 / 306 ) Persian Restaurants in Grymes Hill, Staten Island:0
# ['Staten Island', 'Grymes Hill', 40.624184791313006, -74.08724819983729]
# ( 204 / 306 ) Persian Restaurants in Todt Hill, Staten Island:0
# ['Staten Island', 'Todt Hill', 40.59706851814673, -74.1113288180088]
# ( 205 / 306 ) Persian Restaurants in South Beach, Staten Island:0
# ['Staten Island', 'South Beach', 40.58024741350956, -74.0795529253982]
# ( 206 / 306 ) Persian Restaurants in Port Richmond, Staten Island:0
# ['Staten Island', 'Port Richmond', 40.63366930554365, -74.12943426797008]
# ( 207 / 306 ) Persian Restaurants in Mariner's Harbor, Staten Island:0
# ['Staten Island', "Mariner's Harbor", 40.632546390481124, -74.15008537046981]
# ( 208 / 306 ) Persian Restaurants in Port Ivory, Staten Island:0
# ['Staten Island', 'Port Ivory', 40.63968297845542, -74.17464532993542]
# ( 209 / 306 ) Persian Restaurants in Castleton Corners, Staten Island:0
# ['Staten Island', 'Castleton Corners', 40.61333593766742, -74.11918058534842]
# ( 210 / 306 ) Persian Restaurants in New Springville, Staten Island:0
# ['Staten Island', 'New Springville', 40.594252379161695, -74.16496031329827]
# ( 211 / 306 ) Persian Restaurants in Travis, Staten Island:0
# ['Staten Island', 'Travis', 40.58631375103281, -74.19073717538116]
# ( 212 / 306 ) Persian Restaurants in New Dorp, Staten Island:0
# ['Staten Island', 'New Dorp', 40.57257231820632, -74.1164794360638]
# ( 213 / 306 ) Persian Restaurants in Oakwood, Staten Island:0
# ['Staten Island', 'Oakwood', 40.5584622432888, -74.12156593771896]
# ( 214 / 306 ) Persian Restaurants in Great Kills, Staten Island:0
# ['Staten Island', 'Great Kills', 40.549480228713605, -74.14932381490992]
# ( 215 / 306 ) Persian Restaurants in Eltingville, Staten Island:0
# ['Staten Island', 'Eltingville', 40.542230747450745, -74.1643308041936]
# ( 216 / 306 ) Persian Restaurants in Annadale, Staten Island:0
# ['Staten Island', 'Annadale', 40.53811417474507, -74.17854866165878]
# ( 217 / 306 ) Persian Restaurants in Woodrow, Staten Island:0
# ['Staten Island', 'Woodrow', 40.541967622888755, -74.20524582480326]
# ( 218 / 306 ) Persian Restaurants in Tottenville, Staten Island:0
# ['Staten Island', 'Tottenville', 40.50533376115642, -74.24656934235283]
# ( 219 / 306 ) Persian Restaurants in Tompkinsville, Staten Island:0
# ['Staten Island', 'Tompkinsville', 40.637316067110326, -74.08055351790115]
# ( 220 / 306 ) Persian Restaurants in Silver Lake, Staten Island:0
# ['Staten Island', 'Silver Lake', 40.61919310792676, -74.09629029235458]
# ( 221 / 306 ) Persian Restaurants in Sunnyside, Staten Island:0
# ['Staten Island', 'Sunnyside', 40.61276015756489, -74.0971255217853]
# ( 222 / 306 ) Persian Restaurants in Ditmas Park, Brooklyn:0
# ['Brooklyn', 'Ditmas Park', 40.643675183340974, -73.96101312466779]
# ( 223 / 306 ) Persian Restaurants in Wingate, Brooklyn:0
# ['Brooklyn', 'Wingate', 40.66094656188111, -73.93718680559314]
# ( 224 / 306 ) Persian Restaurants in Rugby, Brooklyn:0
# ['Brooklyn', 'Rugby', 40.655572313280764, -73.92688212616955]
# ( 225 / 306 ) Persian Restaurants in Park Hill, Staten Island:0
# ['Staten Island', 'Park Hill', 40.60919044434558, -74.08015734936296]
# ( 226 / 306 ) Persian Restaurants in Westerleigh, Staten Island:0
# ['Staten Island', 'Westerleigh', 40.62109047275409, -74.13304143951704]
# ( 227 / 306 ) Persian Restaurants in Graniteville, Staten Island:0
# ['Staten Island', 'Graniteville', 40.620171512231884, -74.15315246387762]
# ( 228 / 306 ) Persian Restaurants in Arlington, Staten Island:0
# ['Staten Island', 'Arlington', 40.63532509911492, -74.16510420241124]
# ( 229 / 306 ) Persian Restaurants in Arrochar, Staten Island:1
# ['Staten Island', 'Arrochar', 40.596312571276734, -74.06712363225574]
# ( 230 / 306 ) Persian Restaurants in Grasmere, Staten Island:0
# ['Staten Island', 'Grasmere', 40.59826835959991, -74.0766743627905]
# ( 231 / 306 ) Persian Restaurants in Old Town, Staten Island:0
# ['Staten Island', 'Old Town', 40.59632891379513, -74.08751118005578]
# ( 232 / 306 ) Persian Restaurants in Dongan Hills, Staten Island:0
# ['Staten Island', 'Dongan Hills', 40.588672948199275, -74.09639905312521]
# ( 233 / 306 ) Persian Restaurants in Midland Beach, Staten Island:0
# ['Staten Island', 'Midland Beach', 40.57352690574283, -74.09348266303591]
# ( 234 / 306 ) Persian Restaurants in Grant City, Staten Island:0
# ['Staten Island', 'Grant City', 40.57621558711788, -74.10585598545434]
# ( 235 / 306 ) Persian Restaurants in New Dorp Beach, Staten Island:0
# ['Staten Island', 'New Dorp Beach', 40.56425549307335, -74.10432707469124]
# ( 236 / 306 ) Persian Restaurants in Bay Terrace, Staten Island:0
# ['Staten Island', 'Bay Terrace', 40.55398800858462, -74.13916622175768]
# ( 237 / 306 ) Persian Restaurants in Huguenot, Staten Island:0
# ['Staten Island', 'Huguenot', 40.531911920489605, -74.19174105747814]
# ( 238 / 306 ) Persian Restaurants in Pleasant Plains, Staten Island:0
# ['Staten Island', 'Pleasant Plains', 40.524699376118136, -74.21983106616777]
# ( 239 / 306 ) Persian Restaurants in Butler Manor, Staten Island:0
# ['Staten Island', 'Butler Manor', 40.50608165346305, -74.22950350260027]
# ( 240 / 306 ) Persian Restaurants in Charleston, Staten Island:0
# ['Staten Island', 'Charleston', 40.53053148283314, -74.23215775896526]
# ( 241 / 306 ) Persian Restaurants in Rossville, Staten Island:0
# ['Staten Island', 'Rossville', 40.54940400650072, -74.21572851113952]
# ( 242 / 306 ) Persian Restaurants in Arden Heights, Staten Island:0
# ['Staten Island', 'Arden Heights', 40.54928582278321, -74.18588674583893]
# ( 243 / 306 ) Persian Restaurants in Greenridge, Staten Island:0
# ['Staten Island', 'Greenridge', 40.555295236173194, -74.17079414786092]
# ( 244 / 306 ) Persian Restaurants in Heartland Village, Staten Island:0
# ['Staten Island', 'Heartland Village', 40.58913894875281, -74.15902208156601]
# ( 245 / 306 ) Persian Restaurants in Chelsea, Staten Island:0
# ['Staten Island', 'Chelsea', 40.59472602746295, -74.1895604551969]
# ( 246 / 306 ) Persian Restaurants in Bloomfield, Staten Island:0
# ['Staten Island', 'Bloomfield', 40.60577868452358, -74.18725638381567]
# ( 247 / 306 ) Persian Restaurants in Bulls Head, Staten Island:0
# ['Staten Island', 'Bulls Head', 40.6095918004203, -74.15940948657122]
# ( 248 / 306 ) Persian Restaurants in Carnegie Hill, Manhattan:0
# ['Manhattan', 'Carnegie Hill', 40.7826825671257, -73.95325646837112]
# ( 249 / 306 ) Persian Restaurants in Noho, Manhattan:0
# ['Manhattan', 'Noho', 40.72325901885768, -73.98843368023597]
# ( 250 / 306 ) Persian Restaurants in Civic Center, Manhattan:0
# ['Manhattan', 'Civic Center', 40.71522892046282, -74.00541529873355]
# ( 251 / 306 ) Persian Restaurants in Midtown South, Manhattan:1
# ['Manhattan', 'Midtown South', 40.7485096643122, -73.98871313285247]
# ( 252 / 306 ) Persian Restaurants in Richmond Town, Staten Island:0
# ['Staten Island', 'Richmond Town', 40.56960594275505, -74.1340572986257]
# ( 253 / 306 ) Persian Restaurants in Shore Acres, Staten Island:0
# ['Staten Island', 'Shore Acres', 40.60971934079284, -74.06667766061771]
# ( 254 / 306 ) Persian Restaurants in Clifton, Staten Island:0
# ['Staten Island', 'Clifton', 40.61917845202843, -74.072642445484]
# ( 255 / 306 ) Persian Restaurants in Concord, Staten Island:0
# ['Staten Island', 'Concord', 40.6044731896879, -74.08402364740358]
# ( 256 / 306 ) Persian Restaurants in Emerson Hill, Staten Island:0
# ['Staten Island', 'Emerson Hill', 40.606794394801, -74.09776206972522]
# ( 257 / 306 ) Persian Restaurants in Randall Manor, Staten Island:0
# ['Staten Island', 'Randall Manor', 40.63563000681151, -74.09805062373887]
# ( 258 / 306 ) Persian Restaurants in Howland Hook, Staten Island:0
# ['Staten Island', 'Howland Hook', 40.63843283794795, -74.18622331749823]
# ( 259 / 306 ) Persian Restaurants in Elm Park, Staten Island:0
# ['Staten Island', 'Elm Park', 40.630146741193826, -74.1418167896889]
# ( 260 / 306 ) Persian Restaurants in Remsen Village, Brooklyn:0
# ['Brooklyn', 'Remsen Village', 40.652117451793494, -73.91665331978048]
# ( 261 / 306 ) Persian Restaurants in New Lots, Brooklyn:0
# ['Brooklyn', 'New Lots', 40.6627442796966, -73.88511776379292]
# ( 262 / 306 ) Persian Restaurants in Paerdegat Basin, Brooklyn:0
# ['Brooklyn', 'Paerdegat Basin', 40.63131755039667, -73.90233474295836]
# ( 263 / 306 ) Persian Restaurants in Mill Basin, Brooklyn:0
# ['Brooklyn', 'Mill Basin', 40.61597423962336, -73.91515391550404]
# ( 264 / 306 ) Persian Restaurants in Jamaica Hills, Queens:0
# ['Queens', 'Jamaica Hills', 40.71145964370482, -73.79646462081593]
# ( 265 / 306 ) Persian Restaurants in Utopia, Queens:0
# ['Queens', 'Utopia', 40.73350025429757, -73.79671678028349]
# ( 266 / 306 ) Persian Restaurants in Pomonok, Queens:0
# ['Queens', 'Pomonok', 40.73493618075478, -73.80486120040537]
# ( 267 / 306 ) Persian Restaurants in Astoria Heights, Queens:0
# ['Queens', 'Astoria Heights', 40.7703173929982, -73.89467996270574]
# ( 268 / 306 ) Persian Restaurants in Claremont Village, Bronx:0
# ['Bronx', 'Claremont Village', 40.83142834161548, -73.90119903387667]
# ( 269 / 306 ) Persian Restaurants in Concourse Village, Bronx:0
# ['Bronx', 'Concourse Village', 40.824780490842905, -73.91584652759009]
# ( 270 / 306 ) Persian Restaurants in Mount Eden, Bronx:0
# ['Bronx', 'Mount Eden', 40.84382617671654, -73.91655551964419]
# ( 271 / 306 ) Persian Restaurants in Mount Hope, Bronx:0
# ['Bronx', 'Mount Hope', 40.84884160724665, -73.90829930881988]
# ( 272 / 306 ) Persian Restaurants in Sutton Place, Manhattan:1
# ['Manhattan', 'Sutton Place', 40.76028033131374, -73.96355614094303]
# ( 273 / 306 ) Persian Restaurants in Hunters Point, Queens:0
# ['Queens', 'Hunters Point', 40.743414090073536, -73.95386782130745]
# ( 274 / 306 ) Persian Restaurants in Turtle Bay, Manhattan:0
# ['Manhattan', 'Turtle Bay', 40.75204236950722, -73.96770824581834]
# ( 275 / 306 ) Persian Restaurants in Tudor City, Manhattan:0
# ['Manhattan', 'Tudor City', 40.746917410740195, -73.97121928722265]
# ( 276 / 306 ) Persian Restaurants in Stuyvesant Town, Manhattan:0
# ['Manhattan', 'Stuyvesant Town', 40.73099955477061, -73.97405170469203]
# ( 277 / 306 ) Persian Restaurants in Flatiron, Manhattan:4
# ['Manhattan', 'Flatiron', 40.739673047638426, -73.9909471052826]
# ( 278 / 306 ) Persian Restaurants in Sunnyside Gardens, Queens:0
# ['Queens', 'Sunnyside Gardens', 40.74565180608076, -73.91819286431682]
# ( 279 / 306 ) Persian Restaurants in Blissville, Queens:0
# ['Queens', 'Blissville', 40.73725071694497, -73.93244235260178]
# ( 280 / 306 ) Persian Restaurants in Fulton Ferry, Brooklyn:0
# ['Brooklyn', 'Fulton Ferry', 40.70328109093014, -73.99550751888415]
# ( 281 / 306 ) Persian Restaurants in Vinegar Hill, Brooklyn:0
# ['Brooklyn', 'Vinegar Hill', 40.70332149882874, -73.98111603592393]
# ( 282 / 306 ) Persian Restaurants in Weeksville, Brooklyn:0
# ['Brooklyn', 'Weeksville', 40.67503986503237, -73.93053108817338]
# ( 283 / 306 ) Persian Restaurants in Broadway Junction, Brooklyn:0
# ['Brooklyn', 'Broadway Junction', 40.67786104769531, -73.90331684852599]
# ( 284 / 306 ) Persian Restaurants in Dumbo, Brooklyn:1
# ['Brooklyn', 'Dumbo', 40.70317632822692, -73.9887528074504]
# ( 285 / 306 ) Persian Restaurants in Manor Heights, Staten Island:0
# ['Staten Island', 'Manor Heights', 40.60180957631444, -74.12059399718001]
# ( 286 / 306 ) Persian Restaurants in Willowbrook, Staten Island:0
# ['Staten Island', 'Willowbrook', 40.60370692627371, -74.13208447484298]
# ( 287 / 306 ) Persian Restaurants in Sandy Ground, Staten Island:0
# ['Staten Island', 'Sandy Ground', 40.541139922091766, -74.21776636068567]
# ( 288 / 306 ) Persian Restaurants in Egbertville, Staten Island:0
# ['Staten Island', 'Egbertville', 40.579118742961214, -74.12727240604946]
# ( 289 / 306 ) Persian Restaurants in Roxbury, Queens:0
# ['Queens', 'Roxbury', 40.56737588957032, -73.89213760232822]
# ( 290 / 306 ) Persian Restaurants in Homecrest, Brooklyn:0
# ['Brooklyn', 'Homecrest', 40.598525095137255, -73.95918459428702]
# ( 291 / 306 ) Persian Restaurants in Middle Village, Queens:0
# ['Queens', 'Middle Village', 40.716414511158185, -73.88114319200604]
# ( 292 / 306 ) Persian Restaurants in Prince's Bay, Staten Island:0
# ['Staten Island', "Prince's Bay", 40.52626406734812, -74.20152556457658]
# ( 293 / 306 ) Persian Restaurants in Lighthouse Hill, Staten Island:0
# ['Staten Island', 'Lighthouse Hill', 40.57650629379489, -74.13792663771568]
# ( 294 / 306 ) Persian Restaurants in Richmond Valley, Staten Island:0
# ['Staten Island', 'Richmond Valley', 40.51954145748909, -74.22957080626941]
# ( 295 / 306 ) Persian Restaurants in Malba, Queens:0
# ['Queens', 'Malba', 40.79060155670148, -73.82667757138641]
# ( 296 / 306 ) Persian Restaurants in Highland Park, Brooklyn:0
# ['Brooklyn', 'Highland Park', 40.6819989345173, -73.890345709872]
# ( 297 / 306 ) Persian Restaurants in Madison, Brooklyn:0
# ['Brooklyn', 'Madison', 40.60937770113766, -73.94841515328893]
# ( 298 / 306 ) Persian Restaurants in Bronxdale, Bronx:0
# ['Bronx', 'Bronxdale', 40.85272297633017, -73.86172577555115]
# ( 299 / 306 ) Persian Restaurants in Allerton, Bronx:0
# ['Bronx', 'Allerton', 40.86578787802982, -73.85931863221647]
# ( 300 / 306 ) Persian Restaurants in Kingsbridge Heights, Bronx:0
# ['Bronx', 'Kingsbridge Heights', 40.8703923914147, -73.90152264513144]
# ( 301 / 306 ) Persian Restaurants in Erasmus, Brooklyn:0
# ['Brooklyn', 'Erasmus', 40.64692606658579, -73.94817709920184]
# ( 302 / 306 ) Persian Restaurants in Hudson Yards, Manhattan:0
# ['Manhattan', 'Hudson Yards', 40.75665808227519, -74.00011136202637]
# ( 303 / 306 ) Persian Restaurants in Hammels, Queens:0
# ['Queens', 'Hammels', 40.58733774018741, -73.80553002968718]
# ( 304 / 306 ) Persian Restaurants in Bayswater, Queens:0
# ['Queens', 'Bayswater', 40.611321691283834, -73.76596781445627]
# ( 305 / 306 ) Persian Restaurants in Queensbridge, Queens:0
# ['Queens', 'Queensbridge', 40.756091297094706, -73.94563070334091]
# ( 306 / 306 ) Persian Restaurants in Fox Hills, Staten Island:0
# ['Staten Island', 'Fox Hills', 40.61731079252983, -74.08173992211962]

# %% [markdown]
# Since we have limited amount of calls in Foursquare, I'm going to save this data as .csv for our reference:

# %%
#saving the information to a .csv file 
persian_rest_nyc.to_csv('persian_rest_nyc_tocsv1.csv')

# %%
#let's have a glance of our data
persian_nyc = pd.read_csv('persian_rest_nyc_tocsv1.csv')
persian_rest_nyc.head()
# Out:
#     Borough       Neighborhood                        ID  \
# 0  Brooklyn     Brighton Beach  4c819efadc018cfae6ddc76c
# 1  Brooklyn           Bushwick  59c58cc2bd40097ff68f8466
# 2  Brooklyn  East Williamsburg  51353096e4b0885722745260
# 3  Brooklyn         North Side  5f2dd84ac551a43bd01f03d8
# 4  Brooklyn         South Side  5f2dd84ac551a43bd01f03d8
#
#                      Name
# 0     Beyti Turkish Kebab
# 1                   Zatar
# 2  Healthy Choice Kitchen
# 3             Strangeways
# 4             Strangeways

# %%
persian_rest_nyc.shape
# Out:
# (39, 4)

# %% [markdown]
# There are 39 Mediterranean restuarants in NYC.
#
# Now let's see how many are in each New York City's Borough:

# %%
persian_rest_nyc.groupby('Borough')['ID'].count().plot.bar(figsize=(12,6), color='blue')
plt.title('Mediterranean Restaurants per Borough: NYC', fontsize = 18)
plt.xlabel('Borough', fontsize = 14)
plt.ylabel('Number of Mediterranean Restaurants', fontsize=14)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %% [markdown]
# So as you can see Manhattan has the most number of Mediterranean restuarants! Although Manhattan is relatively a small Borough it has around 25 mediterranean restuarants!

# %%
persian_rest_nyc.groupby('Borough')['Neighborhood'].count()
# Out:
# Borough
# Brooklyn          6
# Manhattan        27
# Queens            5
# Staten Island     1
# Name: Neighborhood, dtype: int64

# %%
NumofNeigh = 10 #showing 10 neighborhoods on the graphs
persian_rest_nyc.groupby('Neighborhood')['ID'].count().nlargest(NumofNeigh).plot.bar(figsize=(14,5), color='blue')
plt.title('Mediterranean Restaurants per Neighborhood- NYC', fontsize = 18)
plt.xlabel('Neighborhood', fontsize = 14)
plt.ylabel('Number of Mediterranean Restaurants', fontsize=14)
plt.xticks(rotation = 'horizontal')
plt.legend()
plt.show()

# %% [markdown]
# Flatiron and Soho neighborhoods have the highest number of Mediterranean restuarants.
# Let's just pick the top 5 neighborhoods and check out the restuarants:

# %%
persian_rest_nyc[persian_rest_nyc['Neighborhood']=='Flatiron']
# Out:
#       Borough Neighborhood                        ID                  Name
# 34  Manhattan     Flatiron  5c5869388b98fd002c5de209                  CAVA
# 35  Manhattan     Flatiron  4ae32479f964a520e09021e3             Barbounia
# 36  Manhattan     Flatiron  573363c2498eb18e283007f8                  Bite
# 37  Manhattan     Flatiron  4f331c5ce4b05255bdf07d27  The Hummus & Pita Co

# %%
persian_rest_nyc[persian_rest_nyc['Neighborhood']=='Soho']
# Out:
#       Borough Neighborhood                        ID               Name
# 18  Manhattan         Soho  4a05ea5cf964a5209b721fe3     Antique Garage
# 19  Manhattan         Soho  4f0f47650cd695a0e54cb438  Jack's Wife Freda
# 20  Manhattan         Soho  5b9ef2d9f8cbd4002c8c7c1e       19 Cleveland
# 21  Manhattan         Soho  59e0ee84f0ca95526b7fce9f               CAVA

# %%
persian_rest_nyc[persian_rest_nyc['Neighborhood']=='Clinton']
# Out:
#       Borough Neighborhood                        ID  \
# 10  Manhattan      Clinton  56aff9ef498e60c01f7b2a21
# 11  Manhattan      Clinton  4f05ed7fd3e321b78fda80b0
#
#                          Name
# 10         Mémé Mediterranean
# 11  Turco Mediterranean Grill

# %%
persian_rest_nyc[persian_rest_nyc['Neighborhood']=='Financial District']
# Out:
#       Borough        Neighborhood                        ID  \
# 25  Manhattan  Financial District  5cf62af9cb3fd2002c8e8a4c
# 26  Manhattan  Financial District  5187b7ca498e26e78cc393a9
#
#                          Name
# 25                       CAVA
# 26  Roti Modern Mediterranean

# %%
persian_rest_nyc[persian_rest_nyc['Neighborhood']=='Little Italy']
# Out:
#       Borough  Neighborhood                        ID          Name
# 16  Manhattan  Little Italy  5b9ef2d9f8cbd4002c8c7c1e  19 Cleveland
# 17  Manhattan  Little Italy  59e0ee84f0ca95526b7fce9f          CAVA

# %% [markdown]
# I can see that there's almost one 'CAVA' in the neighborhoods! out of curiosity I'm going to see out of 39 overall Mediterranean restaurants how many 'CAVA' restaurants are there?!

# %%
persian_rest_nyc[persian_rest_nyc['Name']=='CAVA']
# Out:
#       Borough        Neighborhood                        ID  Name
# 12  Manhattan             Midtown  5b9fe1ef93bd63002c3bbb7b  CAVA
# 17  Manhattan        Little Italy  59e0ee84f0ca95526b7fce9f  CAVA
# 21  Manhattan                Soho  59e0ee84f0ca95526b7fce9f  CAVA
# 25  Manhattan  Financial District  5cf62af9cb3fd2002c8e8a4c  CAVA
# 34  Manhattan            Flatiron  5c5869388b98fd002c5de209  CAVA

# %% [markdown]
# So there are 5 'CAVA' restuarants and all are in Manhattan!
#
# Let's look at how many unique Mediterranean restaurants we have:

# %%
persian_rest_nyc.Name.unique()
# Out:
# array(['Gurra Cafe', 'Beyti Turkish Kebab', 'Zatar',
#        'Healthy Choice Kitchen', 'Strangeways', 'Trufa', 'Flora Bar',
#        'Mokum', 'Boulud Sud', 'Mémé Mediterranean',
#        'Turco Mediterranean Grill', 'CAVA',
#        "Omar's Mediterranean Cuisine", 'Shuka', 'Zyara Restaurant & Cafe',
#        '19 Cleveland', 'Antique Garage', "Jack's Wife Freda",
#        'Elysian Fields Cafe', 'Atrio New York',
#        'Roti Modern Mediterranean', 'Farid Kebab, Steinway', 'Chickpea',
#        "Maria's Restaurant", 'Painico Cafe', 'Seaside Turkish Restaurant',
#        'Pergola', 'Anassa Taverna', 'Barbounia', 'Bite',
#        'The Hummus & Pita Co', 'Celestine'], dtype=object)

# %% [markdown]
# There are 32 unique restaurants so some of them are chain restuarants such as 'CAVA'!

# %% [markdown]
# Now let's get into more detail and see which one of these restaurants have the highest ranking:

# %%
column_names=['Borough', 'Neighborhood', 'ID','Name','Likes','Rating','Tips']
persian_rest_stats_nyc=pd.DataFrame(columns=column_names)
count=1
for row in persian_rest_nyc.values.tolist():
    Borough,Neighborhood,ID,Name=row
    try:
        venue_details=get_venue_details(ID)
        print(venue_details)
        id,name,likes,rating,tips=venue_details.values.tolist()[0]
    except IndexError:
        print('No data available for id=',ID)
        #I will assign 0 value for these resturants as they may have been 
        #opened recently or information doesn't exist in FourSquare Database
        id,name,likes,rating,tips=[0]*5
    print('(',count,'/',len(persian_rest_nyc),')','processed')
    persian_rest_stats_nyc = persian_rest_stats_nyc.append({'Borough': Borough,
                                                'Neighborhood': Neighborhood, 
                                                'ID': id,
                                                'Name' : name,
                                                'Likes' : likes,
                                                'Rating' : rating,
                                                'Tips' : tips
                                               }, ignore_index=True)
    count+=1
persian_rest_stats_nyc.tail()
# Out:
# {'meta': {'code': 200, 'requestId': '5fe24ac776cf540ef1815881'}, 'response': {'venue': {'id': '4c819efadc018cfae6ddc76c', 'name': 'Beyti Turkish Kebab', 'contact': {'phone': '7183327900', 'formattedPhone': '(718) 332-7900', 'twitter': 'bturkishkebab'}, 'location': {'address': '414 Brighton Beach Ave', 'lat': 40.57725621107341, 'lng': -73.96273041029376, 'labeledLatLngs': [{'label': 'display', 'lat': 40.57725621107341, 'lng': -73.96273041029376}], 'postalCode': '11235', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['414 Brighton Beach Ave', 'Brooklyn, NY 11235', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/beyti-turkish-kebab/4c819efadc018cfae6ddc76c', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d115941735', 'name': 'Middle Eastern Restaurant', 'pluralName': 'Middle Eastern Restaurants', 'shortName': 'Middle Eastern', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_', 'suffix': '.png'}}, {'id': '4bf58dd8d48988d1cb941735', 'name': 'Food Truck', 'pluralName': 'Food Trucks', 'shortName': 'Food Truck', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 26}, 'url': 'http://beytiturkishkebab-hub.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 58, 'groups': [{'type': 'others', 'count': 58, 'items': []}], 'summary': '58 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 87, 'delivery': {'id': '276601', 'url': 'https://www.seamless.com/menu/beyti-turkish-kebab-414-brighton-beach-ave-brooklyn/276601?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=276601', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 30, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 30, 'items': [{'id': '55c01730498ee756f16daaf3', 'createdAt': 1438652208, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/135902144_6M991BHjuUzn1kQyw7lTmqU_HoVlg9aSpZZ6bSORwAM.jpg', 'width': 1920, 'height': 1440, 'user': {'firstName': 'Nina', 'lastName': 'A', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '78220824'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'We offer you Mediterranean cuisine hospitality, friendliness, and the rich mosaic of cultures and traditions.', 'page': {'user': {'firstName': 'Beyti Turkish Kebab', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4c819efadc018cfae6ddc76c'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1283563258, 'tips': {'count': 26, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 26, 'items': [{'id': '5e0d0002e070f700097a73d6', 'createdAt': 1577910274, 'text': 'All the kebabs are fantastic, and the chicken soup is INCREDIBLE', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5e0d0002e070f700097a73d6', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Fikret', 'lastName': 'O', 'countryCode': 'US'}]}], 'summary': '1  ...
#                          ID                 Name  Likes  Rating  Tips
# 0  4c819efadc018cfae6ddc76c  Beyti Turkish Kebab     58     8.1    26
# ( 1 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac73577fa053ce51c91'}, 'response': {'venue': {'id': '59c58cc2bd40097ff68f8466', 'name': 'Zatar', 'contact': {}, 'location': {'lat': 40.698, 'lng': -73.92455, 'labeledLatLngs': [{'label': 'display', 'lat': 40.698, 'lng': -73.92455}], 'postalCode': '11221', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['Brooklyn, NY 11221', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/zatar/59c58cc2bd40097ff68f8466', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 4}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 13, 'groups': [{'type': 'others', 'count': 13, 'items': []}], 'summary': '13 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 18, 'delivery': {'id': '515765', 'url': 'https://www.seamless.com/menu/zatar-grill-1294-myrtle-ave-brooklyn/515765?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=515765', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 15, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 15, 'items': [{'id': '5fc84c5130661c682c21402a', 'createdAt': 1606962257, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/21397345_fsspB7CZd_Z85rzPkmt0cOIyJl-I_25liu5a7jkLhfI.jpg', 'width': 1440, 'height': 1920, 'user': {'firstName': 'David', 'lastName': 'C', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1506118850, 'tips': {'count': 4, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 4, 'items': [{'id': '5ba980815ba046002c3aaa4d', 'createdAt': 1537835137, 'text': 'Amazing food at amazing prices!!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5ba980815ba046002c3aaa4d', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Stefan', 'lastName': 'S', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/2xuqHVv', 'timeZone': 'America/New_York', 'listed': {'count': 9, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 9, 'items': [{'id': '5978dbc35a2c91628babcf34', 'name': 'Bushwick', 'description': '', 'type': 'others', 'user': {'firstName': 'Susanna', 'lastName': 'A', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/s00sanna/list/bushwick', 'canonicalUrl': 'https://foursquare.com/s00sanna/list/bushwick', 'createdAt': 1501092803, 'updatedAt': 1529080710, 'photo': {'id': '51be35ae498edaf0556fd393', 'createdAt': 1371420078, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/58735802_DPiEbWVQbPKZXy6jMTO8Lj3XSm6j3Qeg5wuLILFOwgE.jpg', 'width': 960, 'height': 720, 'user': {'firstName': 'Seth', 'lastName': 'H', 'countryCode': 'US'}, 'visibility': 'public'}, 'followers': {'count': 0}, 'listItems': {'count': 35, 'items': [{'id': 'v59c58cc2bd40097ff68f8466', 'createdAt': 1522523845}]}}, {'id': '58aafe331e1de559341d1ea5', 'name': 'NYC', 'description': 'Places to drag Lauren and Jess and Charles to', 'type': 'others', 'user': {'firstName': 'Naomi', 'lastName': 'B', 'countryCode': 'US'}, 'editable': False, 'public': True, 'c ...
#                          ID   Name  Likes  Rating  Tips
# 0  59c58cc2bd40097ff68f8466  Zatar     13     8.0     4
# ( 2 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac7e73c1a674a2bf37e'}, 'response': {'venue': {'id': '51353096e4b0885722745260', 'name': 'Healthy Choice Kitchen', 'contact': {'phone': '7183020700', 'formattedPhone': '(718) 302-0700'}, 'location': {'address': '181 Graham Ave', 'crossStreet': 'Meserole Streets', 'lat': 40.70845400051191, 'lng': -73.94340056012156, 'labeledLatLngs': [{'label': 'display', 'lat': 40.70845400051191, 'lng': -73.94340056012156}], 'postalCode': '11206', 'cc': 'US', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['181 Graham Ave (Meserole Streets)', 'Brooklyn, NY 11206', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/healthy-choice-kitchen/51353096e4b0885722745260', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 10}, 'url': 'http://healthychoicekitchen.net', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 6.5, 'ratingColor': 'FFC800', 'ratingSignals': 26, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 8, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 8, 'items': [{'id': '5ae27c31625a66002ca6f843', 'createdAt': 1524792369, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/543061_urmc-EqZbh-T2LW6eXz1sqWpcaBB5sUBgQqi-x9WOOI.jpg', 'width': 1865, 'height': 1440, 'user': {'firstName': 'Jeff', 'lastName': 'S', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '80835071'}, 'reasons': {'count': 0, 'items': []}, 'page': {'user': {'firstName': 'Healthy Choice Kitchen', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '51353096e4b0885722745260'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1362440342, 'tips': {'count': 10, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 10, 'items': [{'id': '594ab5cc31fd142efb0f5a08', 'createdAt': 1498068428, 'text': 'As good as other pricier Mediterranean food spots. Delicious, fluffy pitas.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/594ab5cc31fd142efb0f5a08', 'photo': {'id': '594ab5cea8eb60422515c382', 'createdAt': 1498068430, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/433525817_QI0XF8J81lNXSuJlUrZcUAJ1xhmUoKL1e6d8wvWyAWM.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/433525817_QI0XF8J81lNXSuJlUrZcUAJ1xhmUoKL1e6d8wvWyAWM.jpg', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Morgan', 'lastName': 'B', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/YR4F5c', 'timeZone': 'America/New_York', 'listed': {'count': 1, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 1, 'items': [{'id': '5d7abc115cd8ce0006ce1eba', 'name': 'Brooklyn', 'description': '', 'type': 'others', 'user': {'firstName': 'Cecilia', 'lastName': 'F', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/327286751/list/brooklyn', 'canonicalUrl': 'https://foursquare.com/user/327286751/list/brooklyn', 'createdAt': 1568324625, 'updatedAt': 1576687925, ' ...
#                          ID                    Name  Likes  Rating  Tips
# 0  51353096e4b0885722745260  Healthy Choice Kitchen     12     6.5    10
# ( 3 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac84f4f53716bee7fe7'}, 'response': {'venue': {'id': '5f2dd84ac551a43bd01f03d8', 'name': 'Strangeways', 'contact': {'phone': '7183312000', 'formattedPhone': '(718) 331-2000'}, 'location': {'address': '302 Metropolitan Ave', 'lat': 40.714444, 'lng': -73.957887, 'labeledLatLngs': [{'label': 'display', 'lat': 40.714444, 'lng': -73.957887}], 'postalCode': '11211', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['302 Metropolitan Ave', 'New York, NY 11211', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/strangeways/5f2dd84ac551a43bd01f03d8', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 0}, 'url': 'https://www.strangewaysbklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 13, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 17, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 17, 'items': [{'id': '5fd5760a666fe95a7cc379e5', 'createdAt': 1607824906, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2752940_m9OAjtqH95-tZeu4r7kU0QB8M99kFqkyz2XwyEvLErA.jpg', 'width': 1440, 'height': 810, 'user': {'firstName': 'Rob', 'lastName': 'K', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1596840010, 'tips': {'count': 0, 'groups': []}, 'shortUrl': 'https://4sq.com/3a3toz8', 'timeZone': 'America/New_York', 'listed': {'count': 35, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 35, 'items': [{'id': '531f2e3c498e0bd1e4e8bb38', 'name': 'Brooklyn restaurants', 'description': '', 'type': 'others', 'user': {'firstName': 'Jessica', 'lastName': 'F', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/77565384/list/brooklyn-restaurants', 'canonicalUrl': 'https://foursquare.com/user/77565384/list/brooklyn-restaurants', 'createdAt': 1394552380, 'updatedAt': 1608611098, 'followers': {'count': 1}, 'listItems': {'count': 344, 'items': [{'id': 'v5f2dd84ac551a43bd01f03d8', 'createdAt': 1597693466}]}}, {'id': '563c3f49cd10a963594e29e0', 'name': "North Brooklyn To Do's", 'description': '', 'type': 'others', 'user': {'firstName': 'Rachel', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/relevantrachel/list/north-brooklyn-to-dos', 'canonicalUrl': 'https://foursquare.com/relevantrachel/list/north-brooklyn-to-dos', 'createdAt': 1446788937, 'updatedAt': 1608660415, 'photo': {'id': '4f7f34e4e4b043102437772a', 'createdAt': 1333736676, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/VXfpfhw8jKBIJxbv8ZCtGXiG9XZ4H7pZxsHSS7Gg-FA.jpg', 'width': 612, 'height': 612, 'user': {'firstName': 'Lasse', 'lastName': 'K', 'countryCode': 'DK'}, 'visibility': 'public'}, 'followers': {'count': 2}, 'listItems': {'count': 140, 'items': [{'id': 'v5f2dd84ac551a43bd01f03d8', 'createdAt': 1600909959}]}}, {'id': '5d6be4d05cd8ce0006729d5e', 'name': 'New York', 'description': '', 'type': 'others', 'user': {'firstName': 'Jacob', 'lastName': 'P', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/503904430/list/new-york', 'canonicalUrl': 'https://foursquare.com/user/503904430/list/new-york', 'cr ...
#                          ID         Name  Likes  Rating  Tips
# 0  5f2dd84ac551a43bd01f03d8  Strangeways     12     8.5     0
# ( 4 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac8b4359f7d96044a14'}, 'response': {'venue': {'id': '5f2dd84ac551a43bd01f03d8', 'name': 'Strangeways', 'contact': {'phone': '7183312000', 'formattedPhone': '(718) 331-2000'}, 'location': {'address': '302 Metropolitan Ave', 'lat': 40.714444, 'lng': -73.957887, 'labeledLatLngs': [{'label': 'display', 'lat': 40.714444, 'lng': -73.957887}], 'postalCode': '11211', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['302 Metropolitan Ave', 'New York, NY 11211', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/strangeways/5f2dd84ac551a43bd01f03d8', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 0}, 'url': 'https://www.strangewaysbklyn.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 12, 'groups': [{'type': 'others', 'count': 12, 'items': []}], 'summary': '12 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 13, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 17, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 17, 'items': [{'id': '5fd5760a666fe95a7cc379e5', 'createdAt': 1607824906, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/2752940_m9OAjtqH95-tZeu4r7kU0QB8M99kFqkyz2XwyEvLErA.jpg', 'width': 1440, 'height': 810, 'user': {'firstName': 'Rob', 'lastName': 'K', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1596840010, 'tips': {'count': 0, 'groups': []}, 'shortUrl': 'https://4sq.com/3a3toz8', 'timeZone': 'America/New_York', 'listed': {'count': 35, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 35, 'items': [{'id': '531f2e3c498e0bd1e4e8bb38', 'name': 'Brooklyn restaurants', 'description': '', 'type': 'others', 'user': {'firstName': 'Jessica', 'lastName': 'F', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/77565384/list/brooklyn-restaurants', 'canonicalUrl': 'https://foursquare.com/user/77565384/list/brooklyn-restaurants', 'createdAt': 1394552380, 'updatedAt': 1608611098, 'followers': {'count': 1}, 'listItems': {'count': 344, 'items': [{'id': 'v5f2dd84ac551a43bd01f03d8', 'createdAt': 1597693466}]}}, {'id': '563c3f49cd10a963594e29e0', 'name': "North Brooklyn To Do's", 'description': '', 'type': 'others', 'user': {'firstName': 'Rachel', 'lastName': 'W', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/relevantrachel/list/north-brooklyn-to-dos', 'canonicalUrl': 'https://foursquare.com/relevantrachel/list/north-brooklyn-to-dos', 'createdAt': 1446788937, 'updatedAt': 1608660415, 'photo': {'id': '4f7f34e4e4b043102437772a', 'createdAt': 1333736676, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/VXfpfhw8jKBIJxbv8ZCtGXiG9XZ4H7pZxsHSS7Gg-FA.jpg', 'width': 612, 'height': 612, 'user': {'firstName': 'Lasse', 'lastName': 'K', 'countryCode': 'DK'}, 'visibility': 'public'}, 'followers': {'count': 2}, 'listItems': {'count': 140, 'items': [{'id': 'v5f2dd84ac551a43bd01f03d8', 'createdAt': 1600909959}]}}, {'id': '5d6be4d05cd8ce0006729d5e', 'name': 'New York', 'description': '', 'type': 'others', 'user': {'firstName': 'Jacob', 'lastName': 'P', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/503904430/list/new-york', 'canonicalUrl': 'https://foursquare.com/user/503904430/list/new-york', 'cr ...
#                          ID         Name  Likes  Rating  Tips
# 0  5f2dd84ac551a43bd01f03d8  Strangeways     12     8.5     0
# ( 5 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac8d5239e00e2292d52'}, 'response': {'venue': {'id': '4da8ee246e81162ae7b15710', 'name': 'Trufa', 'contact': {'phone': '2122816165', 'formattedPhone': '(212) 281-6165'}, 'location': {'address': '3431 Broadway', 'crossStreet': '139th & 140th Streets', 'lat': 40.823083612129544, 'lng': -73.95295214762749, 'labeledLatLngs': [{'label': 'display', 'lat': 40.823083612129544, 'lng': -73.95295214762749}, {'label': 'entrance', 'lat': 40.823127, 'lng': -73.95318}], 'postalCode': '10031', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['3431 Broadway (139th & 140th Streets)', 'New York, NY 10031', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/trufa/4da8ee246e81162ae7b15710', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d14e941735', 'name': 'American Restaurant', 'pluralName': 'American Restaurants', 'shortName': 'American', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'verified': False, 'stats': {'tipCount': 48}, 'url': 'http://trufarestaurant.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 71, 'groups': [{'type': 'others', 'count': 71, 'items': []}], 'summary': '71 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.1, 'ratingColor': '73CF42', 'ratingSignals': 117, 'delivery': {'id': '258384', 'url': 'https://www.seamless.com/menu/trufa-3431-broadway-ave-new-york/258384?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=258384', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 47, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 47, 'items': [{'id': '503be621e4b0d42a59de3969', 'createdAt': 1346102817, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/RGeBKWZfUmliUyzew0jw9233A3DTGD1tiSC1LVgg-KI.jpg', 'width': 720, 'height': 537, 'user': {'firstName': 'Thalia', 'lastName': 'K', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1302916644, 'tips': {'count': 48, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 48, 'items': [{'id': '4f1b724fe4b0f67a96d0b18c', 'createdAt': 1327198799, 'text': 'Weekend brunch here is fantastic! Fresh squeezed orange juice is the way to go.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/4f1b724fe4b0f67a96d0b18c', 'lang': 'en', 'likes': {'count': 6, 'groups': [{'type': 'others', 'count': 6, 'items': [{'firstName': 'Yanis', 'countryCode': 'US'}, {'firstName': 'W', 'lastName': 'M', 'countryCode': 'US'}, {'firstName': 'Hugo', 'lastName': 'R', 'countryCode': 'US'}]}], 'summary': '6 likes'}, 'logView': True, 'agreeCount': 3, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Rose', 'lastName': 'M', 'countryCode': 'US'}}]}]}, 'shortUrl': 'http://4sq.com/dKi5cJ', 'timeZone': 'America/New_York', 'listed': {'count': 82, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 82, 'items': [{'id': '500d835ae4b03215e74cac3e', 'name': 'Food in harlem', 'description': '', 'type': 'others', 'user': {'firstName': 'Lisa', 'lastName': 'G', 'countryCode': 'US'},  ...
#                          ID   Name  Likes  Rating  Tips
# 0  4da8ee246e81162ae7b15710  Trufa     71     8.1    48
# ( 6 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac9b1fef738c4d9b536'}, 'response': {'venue': {'id': '57fff845d67c8ac5e8f772cb', 'name': 'Flora Bar', 'contact': {'phone': '6465585383', 'formattedPhone': '(646) 558-5383', 'facebook': '992889954143144', 'facebookUsername': 'florabarnyc', 'facebookName': 'Flora Bar'}, 'location': {'address': '945 Madison Ave', 'lat': 40.773596077409636, 'lng': -73.96419416844952, 'labeledLatLngs': [{'label': 'display', 'lat': 40.773596077409636, 'lng': -73.96419416844952}], 'postalCode': '10021', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['945 Madison Ave', 'New York, NY 10021', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/flora-bar/57fff845d67c8ac5e8f772cb', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 26}, 'url': 'http://www.florabarnyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 92, 'groups': [{'type': 'others', 'count': 92, 'items': []}], 'summary': '92 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 131, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 85, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 85, 'items': [{'id': '59f4c9028c35dc0fec033700', 'createdAt': 1509214466, 'source': {'name': 'Swarm for iOS', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/30792_4g5U751ciPcqTOSbdIEnikyjlj37QQYMV0pCY9OyntA.jpg', 'width': 1440, 'height': 1920, 'user': {'firstName': 'Sarah', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1476393029, 'tips': {'count': 26, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 26, 'items': [{'id': '5c49ab09e1f0aa002b381add', 'createdAt': 1548331785, 'text': 'Restaurante dentro do museu. Ótimos pratos, um pouco caros. A sobremesas que é um disco de chocolate com calda de caramelo é indescritível', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c49ab09e1f0aa002b381add', 'photo': {'id': '5c49ab0b4c9be6002c6ac4bd', 'createdAt': 1548331787, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/46131127_ZJoIhNTVvW9VUadkiPpaQsvfjR2zg9piHP3W4JWvQkg.jpg', 'width': 1440, 'height': 1920, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/46131127_ZJoIhNTVvW9VUadkiPpaQsvfjR2zg9piHP3W4JWvQkg.jpg', 'lang': 'pt', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Allan', 'lastName': 'L', 'countryCode': 'BR'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/2e0tk6x', 'timeZone': 'America/New_York', 'listed': {'count': 607, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 607, 'items': [{'id': '503fa0e7e4b023d1ec455a8a', 'name': 'NYC Manhattan East 65th St+', 'description': 'Venues in Upper East Side, Lenox Hill, Carnegie Hill, Yorkville and East Harlem', 'type': 'others', 'user': {'firstName': 'Matthew', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/matthewspassion/list/nyc-manhattan-east-65th-st', 'canonicalUrl': 'https://foursquare.com/matthewspassion/list/nyc-manhattan-east-65th-st', 'createdAt': 1346347239, 'updatedAt': 1568907342, ' ...
#                          ID       Name  Likes  Rating  Tips
# 0  57fff845d67c8ac5e8f772cb  Flora Bar     92     8.6    26
# ( 7 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac978a7474f0193b84b'}, 'response': {'venue': {'id': '5bfde462396de00039fbaf5d', 'name': 'Mokum', 'contact': {}, 'location': {'address': '464 Amsterdam Ave', 'crossStreet': 'W 82nd St', 'lat': 40.785355, 'lng': -73.97681, 'labeledLatLngs': [{'label': 'display', 'lat': 40.785355, 'lng': -73.97681}, {'label': 'entrance', 'lat': 40.785398, 'lng': -73.976888}], 'postalCode': '10024', 'cc': 'US', 'neighborhood': 'Upper West Side', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['464 Amsterdam Ave (W 82nd St)', 'New York, NY 10024', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/mokum/5bfde462396de00039fbaf5d', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 2}, 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 22, 'groups': [{'type': 'others', 'count': 22, 'items': []}], 'summary': '22 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.7, 'ratingColor': '73CF42', 'ratingSignals': 23, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 10, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 10, 'items': [{'id': '5f07af3990a02b480cfbe7f1', 'createdAt': 1594339129, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/65249687_vaCwYcE1bDFJoktzqHMkl2DSvIPQCLDpdZ2WLLsMcOg.jpg', 'width': 1440, 'height': 1920, 'user': {'firstName': 'Jenn', 'lastName': 'K', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 0, 'items': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1543365730, 'tips': {'count': 2, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 2, 'items': [{'id': '5c395c16911fc4002c81d64e', 'createdAt': 1547262998, 'text': 'Reminiscent of Ottolenghi in London. Excellent food in a lovely space.', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5c395c16911fc4002c81d64e', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 2, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Kristina', 'lastName': 'C', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'https://4sq.com/2E1bDTW', 'timeZone': 'America/New_York', 'listed': {'count': 42, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 42, 'items': [{'id': '529959e911d2386cd1c6cba4', 'name': 'NY Bucket List', 'description': '', 'type': 'others', 'user': {'firstName': 'Jacqueline', 'lastName': 'H', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/72701254/list/ny-bucket-list', 'canonicalUrl': 'https://foursquare.com/user/72701254/list/ny-bucket-list', 'createdAt': 1385781737, 'updatedAt': 1600500105, 'photo': {'id': '58321b3601f4330b382eaa6a', 'createdAt': 1479678774, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/13047263_1WmMqRw81P1U5BNFpaziPJBO4rA8L7hgrX_Juupw7-M.jpg', 'width': 1080, 'height': 1920, 'user': {'firstName': 'Maria', 'lastName': 'R', 'address': '', 'city': '', 'state': ''}, 'visibility': 'public'}, 'followers': {'count': 3}, 'listItems': {'count': 125, 'items': [{'id': 'v5bfde462396de00039fbaf5d', 'createdAt': 1580014099}]}}, {'id': '596126dfee628b34951924f4', 'name': 'New York', 'description': '', 'type': 'others', 'user': {'firstName': 'Clara', 'lastName': 'C', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/128510129/list/new-york', 'canonicalUrl': 'https://foursquare.com/user/128510 ...
#                          ID   Name  Likes  Rating  Tips
# 0  5bfde462396de00039fbaf5d  Mokum     22     8.7     2
# ( 8 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ac967c4b002074d6096'}, 'response': {'venue': {'id': '4da8daa5a86e771ea6fdad17', 'name': 'Boulud Sud', 'contact': {'phone': '2125951313', 'formattedPhone': '(212) 595-1313', 'twitter': 'bouludsud', 'facebook': '208212549204096', 'facebookUsername': 'BouludSudNYC', 'facebookName': 'Boulud Sud NYC'}, 'location': {'address': '20 W 64th St', 'crossStreet': 'btwn Broadway & Central Park West', 'lat': 40.77192955953719, 'lng': -73.98157649135018, 'labeledLatLngs': [{'label': 'display', 'lat': 40.77192955953719, 'lng': -73.98157649135018}], 'postalCode': '10023', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['20 W 64th St (btwn Broadway & Central Park West)', 'New York, NY 10023', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/boulud-sud/4da8daa5a86e771ea6fdad17', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 133}, 'url': 'http://www.bouludsud.com', 'price': {'tier': 3, 'message': 'Expensive', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 397, 'groups': [{'type': 'others', 'count': 397, 'items': []}], 'summary': '397 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.5, 'ratingColor': '73CF42', 'ratingSignals': 554, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/boulud-sud/4da8daa5a86e771ea6fdad17/menu', 'mobileUrl': 'https://foursquare.com/v/4da8daa5a86e771ea6fdad17/device_menu', 'externalUrl': 'http://www.bouludsud.com/menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 619, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 619, 'items': [{'id': '525ed5e3498eee99c467f18a', 'createdAt': 1381946851, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/68697291_P5X5Eu6YT7T0VG8LT8_loiV2WfEkbzGw2JJKMUo9Zqs.jpg', 'width': 1024, 'height': 683, 'user': {'firstName': 'Boulud Sud', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4da8daa5a86e771ea6fdad17'}}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '68697291'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Boulud Sud is Chef Daniel Boulud’s vibrant Mediterranean-inspired restaurant featuring flavors that travel the entire Mediterranean region from the shores of Southern France to the coast of North Africa and beyond.', 'page': {'user': {'firstName': 'Boulud Sud', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4da8daa5a86e771ea6fdad17'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1302911653, 'tips': {'count': 133, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 133, 'items': [{'id': '4e8bcc32d22db1c42b0681d5', 'createdAt': 1317784626, 'text': 'Try the Grapefruit Givré, stuffed with rose-scented loukoum and topped with flossy halvah cotton candy and black-and-white sesame tuile. It’s one of our #100best dishes and drinks of 2011.', 'type': 'user', 'url': 'http://tmout.us/oq6N9D', 'canonicalUrl': 'https://foursquare.com/item/4e8bcc32d22db1c42b0681d5', 'lang': 'en', 'likes': {'count': 19, 'groups': [{'type': 'others', 'count': 19, 'items': []}], 'summary': '19 likes'}, 'logView': True, 'agreeCount': 19, 'disagreeCount': 0, 'todo': {'count': 61}, 'user': {'firstName': 'Time Out New York', 'countryCode': 'US', 'type': 'page'}}]}]}, 'shortUrl': 'http://4sq.com/gkQ010',  ...
#                          ID        Name  Likes  Rating  Tips
# 0  4da8daa5a86e771ea6fdad17  Boulud Sud    397     8.5   133
# ( 9 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24aca67c4b002074d61d1'}, 'response': {'venue': {'id': '56aff9ef498e60c01f7b2a21', 'name': 'Mémé Mediterranean', 'contact': {'phone': '9172620827', 'formattedPhone': '(917) 262-0827'}, 'location': {'address': '607 10th Ave', 'crossStreet': 'at 44th St', 'lat': 40.760904754375375, 'lng': -73.99460052237751, 'labeledLatLngs': [{'label': 'display', 'lat': 40.760904754375375, 'lng': -73.99460052237751}, {'label': 'entrance', 'lat': 40.760903, 'lng': -73.994744}], 'postalCode': '10036', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['607 10th Ave (at 44th St)', 'New York, NY 10036', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/m%C3%A9m%C3%A9-mediterranean/56aff9ef498e60c01f7b2a21', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 29}, 'url': 'http://mememediterranean.com/phone/hk_m.html', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 141, 'groups': [{'type': 'others', 'count': 141, 'items': []}], 'summary': '141 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.9, 'ratingColor': '73CF42', 'ratingSignals': 179, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 52, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 52, 'items': [{'id': '5fb4826b1bb8687a307a6b4c', 'createdAt': 1605665387, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/51302306_x_5clB8VoD4U4pcYl_HiIDgXt2G5-9e0JnhEOUnwV4E.jpg', 'width': 1080, 'height': 1440, 'user': {'firstName': 'Melissa', 'lastName': 'T', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1454373359, 'tips': {'count': 29, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 29, 'items': [{'id': '57a79104498e322fe1a97ab9', 'createdAt': 1470599428, 'text': 'Scallops, laffa tacos and the falafel are absolutely amazing!!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/57a79104498e322fe1a97ab9', 'photo': {'id': '57a7910f498ea30d93d2d5ef', 'createdAt': 1470599439, 'source': {'name': 'Foursquare for iOS', 'url': 'https://foursquare.com/download/#/iphone'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/225059827_4SmQkzUERkfZ6v2RmHIt-0oELnzq5u_wAwlRInmZhyQ.jpg', 'width': 1440, 'height': 1440, 'visibility': 'public'}, 'photourl': 'https://fastly.4sqi.net/img/general/original/225059827_4SmQkzUERkfZ6v2RmHIt-0oELnzq5u_wAwlRInmZhyQ.jpg', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Michael', 'lastName': 'L', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 1, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Kathleen', 'lastName': 'S', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1Ty2K3X', 'timeZone': 'America/New_York', 'listed': {'count': 123, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 123, 'items': [{'id': '525e9e5711d223416cedee1d', 'name': 'NYC: Fast Eats & Drinks, Food Shops, Cafés', 'description': '', 'type': 'others', 'user': {'firstName': 'Kaitlyn', 'lastName': 'S', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': False, 'url': '/user/9501871/list/nyc-fast-eats--drinks-food-shops-caf%C3%A9s', 'canonicalUrl': 'https://foursquare.com/use ...
#                          ID                Name  Likes  Rating  Tips
# 0  56aff9ef498e60c01f7b2a21  Mémé Mediterranean    141     8.9    29
# ( 10 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24acada8249517fb362a9'}, 'response': {'venue': {'id': '4f05ed7fd3e321b78fda80b0', 'name': 'Turco Mediterranean Grill', 'contact': {'phone': '2125108666', 'formattedPhone': '(212) 510-8666'}, 'location': {'address': '604 9th Ave', 'crossStreet': 'at W 43rd St', 'lat': 40.75915761782478, 'lng': -73.99202212667944, 'labeledLatLngs': [{'label': 'display', 'lat': 40.75915761782478, 'lng': -73.99202212667944}], 'postalCode': '10036', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['604 9th Ave (at W 43rd St)', 'New York, NY 10036', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/turco-mediterranean-grill/4f05ed7fd3e321b78fda80b0', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}, {'id': '4f04af1f2fb6e1c99f3db0bb', 'name': 'Turkish Restaurant', 'pluralName': 'Turkish Restaurants', 'shortName': 'Turkish', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 57}, 'url': 'http://turconyc.com', 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 112, 'groups': [{'type': 'others', 'count': 112, 'items': []}], 'summary': '112 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.0, 'ratingColor': '73CF42', 'ratingSignals': 178, 'delivery': {'id': '299223', 'url': 'https://www.seamless.com/menu/turco-mediterranean-grill-604-9th-ave-new-york/299223?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=299223', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/turco-mediterranean-grill/4f05ed7fd3e321b78fda80b0/menu', 'mobileUrl': 'https://foursquare.com/v/4f05ed7fd3e321b78fda80b0/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 115, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 115, 'items': [{'id': '51757dace4b001210327da57', 'createdAt': 1366654380, 'source': {'name': 'Foursquare for Android', 'url': 'https://foursquare.com/download/#/android'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/885855_SvFRq06yYQ6Rn-rQFxBWt6QqUngEcjISq_9bnmImxpw.jpg', 'width': 960, 'height': 720, 'user': {'firstName': 'Norman', 'lastName': 'S', 'countryCode': 'DE'}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '51346578'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Bringing a diverse Turkish and Mediterranean kitchen into the heart of Manhattan, we feature a diverse menu, fun atmosphere and friendly staff. Stop by today!', 'page': {'user': {'firstName': 'Turco Mediterranean Grill', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '4f05ed7fd3e321b78fda80b0'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1325788543, 'tips': {'count': 57, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 57, 'items': [{'id': '502e85a9e4b0265f8b0af048', 'createdAt': 1345226153, 'text': "I'm offended they don't serve tapwater.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/502e85a9e4b0265f8b0af048', 'lang': 'en', 'likes': {'count': 7, 'groups': [{'type': 'others', 'count': 7, 'items': [{'firstName': 'Catherine', 'lastName': 'Q ...
#                          ID                       Name  Likes  Rating  Tips
# 0  4f05ed7fd3e321b78fda80b0  Turco Mediterranean Grill    112     8.0    57
# ( 11 / 39 ) processed
# ...
#                          ID       Name  Likes  Rating  Tips
# 0  4ae32479f964a520e09021e3  Barbounia    613     8.6   208
# ( 36 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ad379763a1bc4be9233'}, 'response': {'venue': {'id': '573363c2498eb18e283007f8', 'name': 'Bite', 'contact': {'phone': '6466492768', 'formattedPhone': '(646) 649-2768', 'twitter': 'biteny', 'instagram': 'bitenyc', 'facebook': '331606430263066', 'facebookUsername': 'biteon14', 'facebookName': 'BITE'}, 'location': {'address': '62 W 22nd St', 'crossStreet': 'at 6th Ave', 'lat': 40.742135733688905, 'lng': -73.993066263182, 'labeledLatLngs': [{'label': 'display', 'lat': 40.742135733688905, 'lng': -73.993066263182}], 'postalCode': '10010', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['62 W 22nd St (at 6th Ave)', 'New York, NY 10010', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/bite/573363c2498eb18e283007f8', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': False, 'stats': {'tipCount': 56}, 'url': 'http://bitenyc.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 193, 'groups': [{'type': 'others', 'count': 193, 'items': []}], 'summary': '193 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.6, 'ratingColor': '73CF42', 'ratingSignals': 268, 'delivery': {'id': '323312', 'url': 'https://www.seamless.com/menu/bite-22-62-w-22nd-st-new-york/323312?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=323312', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 61, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 61, 'items': [{'id': '5f8275000349b662d31a8390', 'createdAt': 1602385152, 'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/13129_SlL0kXBjCVCqiqpP_GzG_W0uD6tVZhzHBEK26OPnXf4.jpg', 'width': 1080, 'height': 719, 'user': {'firstName': 'Amanda', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Quality, fresh food for the health-conscious and the epicurean elite.', 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1462985666, 'tips': {'count': 56, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 56, 'items': [{'id': '590b75341acf116c7af2388a', 'createdAt': 1493923124, 'text': 'The price point for what you get, quality, and how much you get is really stellar. The lunch special is perfect and a perfect price for me!', 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/590b75341acf116c7af2388a', 'lang': 'en', 'likes': {'count': 1, 'groups': [{'type': 'others', 'count': 1, 'items': [{'firstName': 'Andrew', 'lastName': 'A', 'countryCode': 'US'}]}], 'summary': '1 like'}, 'logView': True, 'agreeCount': 10, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Sandy', 'lastName': 'W', 'countryCode': 'US'}, 'authorInteractionType': 'liked'}]}]}, 'shortUrl': 'http://4sq.com/1XlslPt', 'timeZone': 'America/New_York', 'listed': {'count': 139, 'groups': [{'type': 'others', 'name': 'Lists from other people', 'count': 139, 'items': [{'id': '569539e4498e451f8b150457', 'name': 'WeWork Chelsea Lunch Spots', 'description': '', 'type': 'others', 'user': {'firstName': 'Ben', 'lastName': 'K', 'countryCode': 'US'}, 'editable': False, 'public': True, 'collaborative': True, 'url': '/kessler/list/wework-chelsea-lunch-spots', 'canonicalU ...
#                          ID  Name  Likes  Rating  Tips
# 0  573363c2498eb18e283007f8  Bite    193     8.6    56
# ( 37 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ad3e73c1a674a2c1a76'}, 'response': {'venue': {'id': '4f331c5ce4b05255bdf07d27', 'name': 'The Hummus & Pita Co', 'contact': {'phone': '2125107405', 'formattedPhone': '(212) 510-7405', 'twitter': 'hummusandpitaco', 'facebook': '101132510014014', 'facebookUsername': 'TheHummusandPitaco', 'facebookName': 'The Hummus and Pita Co.'}, 'location': {'address': '585 Avenue of the Americas', 'crossStreet': 'btwn 16th & 17th St.', 'lat': 40.739269092703694, 'lng': -73.99549266794614, 'labeledLatLngs': [{'label': 'display', 'lat': 40.739269092703694, 'lng': -73.99549266794614}], 'postalCode': '10011', 'cc': 'US', 'city': 'New York', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['585 Avenue of the Americas (btwn 16th & 17th St.)', 'New York, NY 10011', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/the-hummus--pita-co/4f331c5ce4b05255bdf07d27', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}, {'id': '4bf58dd8d48988d1d3941735', 'name': 'Vegetarian / Vegan Restaurant', 'pluralName': 'Vegetarian / Vegan Restaurants', 'shortName': 'Vegetarian / Vegan', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vegetarian_', 'suffix': '.png'}}], 'verified': True, 'stats': {'tipCount': 128}, 'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'}, 'hasMenu': True, 'likes': {'count': 485, 'groups': [{'type': 'others', 'count': 485, 'items': []}], 'summary': '485 Likes'}, 'dislike': False, 'ok': False, 'rating': 8.2, 'ratingColor': '73CF42', 'ratingSignals': 693, 'delivery': {'id': '2099572', 'url': 'https://www.seamless.com/menu/hummus--pita-co-585-6th-ave-new-york/2099572?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=2099572', 'provider': {'name': 'seamless', 'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/', 'sizes': [40, 50], 'name': '/delivery_provider_seamless_20180129.png'}}}, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://foursquare.com/v/the-hummus--pita-co/4f331c5ce4b05255bdf07d27/menu', 'mobileUrl': 'https://foursquare.com/v/4f331c5ce4b05255bdf07d27/device_menu'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 308, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 308, 'items': [{'id': '504b81fce4b03e4ad9464614', 'createdAt': 1347125756, 'source': {'name': 'Instagram', 'url': 'http://instagram.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/Twlb2TzNYGoayrmP38Amj77ss_cDUKaCwZey5BxPTaE.jpg', 'width': 612, 'height': 612, 'user': {'firstName': 'Shelby', 'countryCode': 'US'}, 'visibility': 'public'}]}]}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'The Hummus & Pita Co. is a new fast-casual restaurant serving up 100% homemade, fresh and healthy cuisine in an inviting, contemporary environment. Combining authentic flavors from across the Mediterranean with a modern-American service style, The Hummus & Pita Co. brings high-quality, flavor-foc...', 'storeId': '', 'page': {'pageInfo': {'description': 'The Hummus and Pita Co. is a healthy Mediterranian eatery in Chelsea at 585 6th Ave. between 16th and 17th. So many ways to love it! (212) 510-7405', 'links': {'count': 0, 'items': []}}, 'user': {'firstName': 'The Hummus and PIta Co.', 'countryCode': 'US', 'type': 'chain', 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1328749660, 'tips': {'count ...
#                          ID                  Name  Likes  Rating  Tips
# 0  4f331c5ce4b05255bdf07d27  The Hummus & Pita Co    485     8.2   128
# ( 38 / 39 ) processed
# {'meta': {'code': 200, 'requestId': '5fe24ad4dad389062dd1b102'}, 'response': {'venue': {'id': '59dd280192e7a97276e4d52f', 'name': 'Celestine', 'contact': {'phone': '7185225356', 'formattedPhone': '(718) 522-5356', 'twitter': 'celestineresto', 'instagram': 'celestinerestaurant', 'facebook': '106899280037225', 'facebookUsername': 'celestinerestaurant', 'facebookName': 'Celestine'}, 'location': {'address': '1 John St', 'crossStreet': 'at Adam St', 'lat': 40.70453731730521, 'lng': -73.98802621918485, 'labeledLatLngs': [{'label': 'display', 'lat': 40.70453731730521, 'lng': -73.98802621918485}], 'postalCode': '11201', 'cc': 'US', 'neighborhood': 'DUMBO', 'city': 'Brooklyn', 'state': 'NY', 'country': 'United States', 'formattedAddress': ['1 John St (at Adam St)', 'Brooklyn, NY 11201', 'United States']}, 'canonicalUrl': 'https://foursquare.com/v/celestine/59dd280192e7a97276e4d52f', 'categories': [{'id': '4bf58dd8d48988d1c0941735', 'name': 'Mediterranean Restaurant', 'pluralName': 'Mediterranean Restaurants', 'shortName': 'Mediterranean', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 26}, 'url': 'http://celestinebk.com', 'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'}, 'likes': {'count': 123, 'groups': [{'type': 'others', 'count': 123, 'items': []}], 'summary': '123 Likes'}, 'dislike': False, 'ok': False, 'rating': 7.9, 'ratingColor': 'C5DE35', 'ratingSignals': 167, 'menu': {'type': 'Menu', 'label': 'Menu', 'anchor': 'View Menu', 'url': 'https://static1.squarespace.com/static/59a82637cf81e0ee532a7099/t/5ac3ed6288251b3d00f59166/1522789730942/Celestine_Dinner_4.2.pdf', 'mobileUrl': 'https://static1.squarespace.com/static/59a82637cf81e0ee532a7099/t/5ac3ed6288251b3d00f59166/1522789730942/Celestine_Dinner_4.2.pdf', 'externalUrl': 'https://static1.squarespace.com/static/59a82637cf81e0ee532a7099/t/5ac3ed6288251b3d00f59166/1522789730942/Celestine_Dinner_4.2.pdf'}, 'allowMenuUrlEdit': True, 'beenHere': {'count': 0, 'unconfirmedCount': 0, 'marked': False, 'lastCheckinExpiredAt': 0}, 'specials': {'count': 0, 'items': []}, 'photos': {'count': 106, 'groups': [{'type': 'venue', 'name': 'Venue photos', 'count': 106, 'items': [{'id': '59f3a5995c1ba205e6b9be87', 'createdAt': 1509139865, 'source': {'name': 'Foursquare Web', 'url': 'https://foursquare.com'}, 'prefix': 'https://fastly.4sqi.net/img/general/', 'suffix': '/460729328_xoNyVuV6uA102bBnKSReN1tcl_DdRlxwcTOOjTkSsrg.jpg', 'width': 5388, 'height': 3597, 'user': {'firstName': 'Celestine', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '59dd280192e7a97276e4d52f'}}, 'visibility': 'public'}]}]}, 'venuePage': {'id': '460729328'}, 'reasons': {'count': 1, 'items': [{'summary': 'Lots of people like this place', 'type': 'general', 'reasonName': 'rawLikesReason'}]}, 'description': 'Celestine is an Eastern Mediterranean restaurant located on the DUMBO waterfront, just under the Manhattan Bridge.', 'page': {'user': {'firstName': 'Celestine', 'countryCode': 'US', 'type': 'venuePage', 'venue': {'id': '59dd280192e7a97276e4d52f'}, 'tips': {'count': 0}, 'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]}, 'bio': ''}}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}, 'createdAt': 1507665921, 'tips': {'count': 26, 'groups': [{'type': 'others', 'name': 'All tips', 'count': 26, 'items': [{'id': '5ca8f862a35f46002515073f', 'createdAt': 1554577506, 'text': "You can't really beat the location on the water.", 'type': 'user', 'canonicalUrl': 'https://foursquare.com/item/5ca8f862a35f46002515073f', 'lang': 'en', 'likes': {'count': 0, 'groups': []}, 'logView': True, 'agreeCount': 0, 'disagreeCount': 0, 'todo': {'count': 0}, 'user': {'firstName': 'Stephanie', 'lastName': 'P', 'countryCode': 'US'}, 'authorInteractionType': 'meh'}]}]}, 'shortUrl': 'http://4sq.com/2xw8Qzl', 'timeZone': 'America/New_York', 'listed': {'count': 443, 'groups': [{'type': 'others', 'name' ...
#                          ID       Name  Likes  Rating  Tips
# 0  59dd280192e7a97276e4d52f  Celestine    123     7.9    26
# ( 39 / 39 ) processed
#       Borough Neighborhood                        ID                  Name  \
# 34  Manhattan     Flatiron  5c5869388b98fd002c5de209                  CAVA
# 35  Manhattan     Flatiron  4ae32479f964a520e09021e3             Barbounia
# 36  Manhattan     Flatiron  573363c2498eb18e283007f8                  Bite
# 37  Manhattan     Flatiron  4f331c5ce4b05255bdf07d27  The Hummus & Pita Co
# 38   Brooklyn        Dumbo  59dd280192e7a97276e4d52f             Celestine
#
#    Likes  Rating Tips
# 34    50     8.7    3
# 35   613     8.6  208
# 36   193     8.6   56
# 37   485     8.2  128
# 38   123     7.9   26

# %%
#saving the data to a .csv file
persian_rest_stats_nyc.to_csv('persian_rest_stats_nyc_csv.csv')

# %%
persian_rest_stats_nyc.shape
# Out:
# (39, 7)

# %% [markdown]
# Let's check some information such as data types in our dataframe:

# %%
persian_rest_stats_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       39 non-null     object
#  1   Neighborhood  39 non-null     object
#  2   ID            39 non-null     object
#  3   Name          39 non-null     object
#  4   Likes         39 non-null     object
#  5   Rating        39 non-null     float64
#  6   Tips          39 non-null     object
# dtypes: float64(1), object(6)
# memory usage: 2.3+ KB

# %% [markdown]
# We need to convert the likes, rating and tips data values from string values (objects) to floats, to be able to perform further statical analysis in Python:

# %%
persian_rest_stats_nyc['Likes'] = persian_rest_stats_nyc['Likes'].astype('float64')
persian_rest_stats_nyc['Tips'] = persian_rest_stats_nyc['Tips'].astype('float64')
persian_rest_stats_nyc['Rating']=persian_rest_stats_nyc['Rating'].astype('float64')
persian_rest_stats_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Borough       39 non-null     object
#  1   Neighborhood  39 non-null     object
#  2   ID            39 non-null     object
#  3   Name          39 non-null     object
#  4   Likes         39 non-null     float64
#  5   Rating        39 non-null     float64
#  6   Tips          39 non-null     float64
# dtypes: float64(3), object(4)
# memory usage: 2.3+ KB

# %% [markdown]
# To get more statistical insight, I'm going to use the .describe method to get some overall detail on the Mediterranean restaurants in NYC:

# %%
persian_rest_stats_nyc.describe()
# Out:
#              Likes     Rating        Tips
# count    39.000000  39.000000   39.000000
# mean    167.102564   8.010256   47.871795
# std     296.563013   1.557460   89.094031
# min       0.000000   0.000000    0.000000
# 25%      16.000000   7.800000    3.500000
# 50%      77.000000   8.500000   23.000000
# 75%     157.500000   8.750000   54.500000
# max    1720.000000   9.300000  513.000000

# %%
#restaurant with the most number of Likes
persian_rest_stats_nyc.iloc[persian_rest_stats_nyc['Likes'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                        Soho
# ID              4f0f47650cd695a0e54cb438
# Name                   Jack's Wife Freda
# Likes                               1720
# Rating                               8.7
# Tips                                 513
# Name: 18, dtype: object

# %% [markdown]
# So based on results, Jack's Wife Freda located in Soho (Manhattan) has the highest number of likes. This restuarant has 1,720 likes! The ranting of this restaurant is 8.7 out of 10.
#
# Now let's find the Mediterranean restuarant with the highest ranking:

# %%
#Restaurant with most Ratings
persian_rest_stats_nyc.iloc[persian_rest_stats_nyc['Rating'].idxmax()]
# Out:
# Borough                        Manhattan
# Neighborhood                Little Italy
# ID              59e0ee84f0ca95526b7fce9f
# Name                                CAVA
# Likes                                109
# Rating                               9.3
# Tips                                  13
# Name: 16, dtype: object

# %% [markdown]
# Looks like one of the CAVA restaurants (located in Little Italy in Manhattan) has the highest ranking of 9.3 out of 10.

# %% [markdown]
# Now let's see the average Mediterranean restaurant ratings in different neighborhoods, and which neighborhood has the highest and lowest average ratings:

# %%
nyc_neighborhood_stats=persian_rest_stats_nyc.groupby('Neighborhood',as_index=False).mean()[['Neighborhood','Rating']]
nyc_neighborhood_stats.columns=['Neighborhood','Avg. Rating']
nyc_neighborhood_stats.sort_values(['Avg. Rating'],ascending=False).head(30)
# Out:
#            Neighborhood  Avg. Rating
# 28         West Village        9.300
# 14         Little Italy        9.250
# 20          Murray Hill        9.000
# 11    Greenwich Village        9.000
# 23                 Soho        8.950
# 16      Lower East Side        8.900
# 17              Midtown        8.800
# 27      Upper West Side        8.700
# 26      Upper East Side        8.600
# 10             Flatiron        8.525
# 24           South Side        8.500
# 21           North Side        8.500
# 13       Lincoln Square        8.500
# 6               Clinton        8.450
# 25         Sutton Place        8.300
# 12     Hamilton Heights        8.100
# 4        Brighton Beach        8.100
# 9    Financial District        8.000
# 5              Bushwick        8.000
# 7                 Dumbo        7.900
# 18        Midtown South        7.700
# 2     Battery Park City        7.700
# 1               Astoria        7.500
# 0              Arrochar        6.800
# 15     Long Island City        6.600
# 8     East Williamsburg        6.500
# 19  Morningside Heights        6.400
# 22        Rockaway Park        6.200
# 3               Bayside        3.750

# %% [markdown]
# The results are in and it seems that West Village has the highest average rating among the Mediterranean restaurant (average rating of 9.30). On the other hand, Rockaway Park has the lowest averge ranking of 6.2.
# Soho that is one of the neighborhoods with highest number of Mediterranean restaurants has an average rating of 8.90.

# %%
nyc_borough_stats=persian_rest_stats_nyc.groupby('Borough',as_index=False).mean()[['Borough','Rating']]
nyc_borough_stats.columns=['Borough','Avg. Rating']
nyc_borough_stats.sort_values(['Avg. Rating'],ascending=False).head()
# Out:
#          Borough  Avg. Rating
# 1      Manhattan     8.529630
# 0       Brooklyn     7.916667
# 3  Staten Island     6.800000
# 2         Queens     5.560000

# %% [markdown]
# Looks like Manhattan has the highest average rating among the Mediterranean restuarants!(are we surprised?)
#
# Now let's filter our Neighborhoods with average ratings of 8.5 and higher:

# %%
nyc_neighborhood_stats=nyc_neighborhood_stats[nyc_neighborhood_stats['Avg. Rating']>=8.5]
nyc_neighborhood_stats
# Out:
#          Neighborhood  Avg. Rating
# 10           Flatiron        8.525
# 11  Greenwich Village        9.000
# 13     Lincoln Square        8.500
# 14       Little Italy        9.250
# 16    Lower East Side        8.900
# 17            Midtown        8.800
# 20        Murray Hill        9.000
# 21         North Side        8.500
# 23               Soho        8.950
# 24         South Side        8.500
# 26    Upper East Side        8.600
# 27    Upper West Side        8.700
# 28       West Village        9.300

# %% [markdown]
# It's time to merge this data with our nyc_data to get the latitude and lonitude of restaurants for visualization purposes:

# %%
nyc_neighborhood_stats=pd.merge(nyc_neighborhood_stats,nyc_data, on='Neighborhood')
nyc_neighborhood_stats=nyc_neighborhood_stats[['Borough','Neighborhood','Latitude','Longitude','Avg. Rating']]
nyc_neighborhood_stats
# Out:
#       Borough       Neighborhood   Latitude  Longitude  Avg. Rating
# 0   Manhattan           Flatiron  40.739673 -73.990947        8.525
# 1   Manhattan  Greenwich Village  40.726933 -73.999914        9.000
# 2   Manhattan     Lincoln Square  40.773529 -73.985338        8.500
# 3   Manhattan       Little Italy  40.719324 -73.997305        9.250
# 4   Manhattan    Lower East Side  40.717807 -73.980890        8.900
# 5   Manhattan            Midtown  40.754691 -73.981669        8.800
# 6   Manhattan        Murray Hill  40.748303 -73.978332        9.000
# 7      Queens        Murray Hill  40.764126 -73.812763        9.000
# 8    Brooklyn         North Side  40.714823 -73.958809        8.500
# 9   Manhattan               Soho  40.722184 -74.000657        8.950
# 10   Brooklyn         South Side  40.710861 -73.958001        8.500
# 11  Manhattan    Upper East Side  40.775639 -73.960508        8.600
# 12  Manhattan    Upper West Side  40.787658 -73.977059        8.700
# 13  Manhattan       West Village  40.734434 -74.006180        9.300

# %%
from IPython.display import display, HTML

#creating map using Folium and displaying it
nyc_map = folium.Map(location=geo_location('New York'), zoom_start=12)
#creating a feature group for the ratings in the dataframe
rating = folium.map.FeatureGroup()

# loop through the ratings and add each to the neighborhood feature group
for lat, lng, in nyc_neighborhood_stats[['Latitude','Longitude']].values:
    rating.add_child(
        folium.CircleMarker(
            [lat, lng],
            radius=10, 
            color='red',
            fill=True,
            fill_color='blue',
            fill_opacity=0.6
        )
    )
    
nyc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
nyc_neighborhood_stats['Label']=nyc_neighborhood_stats['Neighborhood']+', '+nyc_neighborhood_stats['Borough']+'('+nyc_neighborhood_stats['Avg. Rating'].map(str)+')'
# add pop-up text to each marker on the map
for lat, lng, label in nyc_neighborhood_stats[['Latitude','Longitude','Label']].values:
    folium.Marker([lat, lng], popup=label).add_to(nyc_map)        
# add ratings to map
nyc_map.add_child(rating)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# So now if we click on any of the tags you can see the name of the neighborbood, its borough and also the Mediterranean restaurants's average ratings!

# %% [markdown]
# ## Results
#
# Based on our data analysis, there re total of 39 Mediterranean restaurants listed in Foursquare API in the city of New York!
# With 27 Mediterranean restaurants, Manhattan has the highest number among other boroughs!
# Soho and Flatiron neighborhoods have highest number of Mediterranean restaurants (5 each!).
# After filtering results, I found out there are 32 unique restuarants, and the remaining 7 are all chain restaurants.
#
# Then I dug into the restaurants details;
# By changing some of the data type values from 'object' to 'float64', I was able to perform some statistical analysis.
# The restaurant with the highest rating is CAVA- located in Little Italy, Manhattan. This location has a rating of 9.30.
# The Jack's Wife Freda located in Soho, Manhattan, has the highest number of 'Likes'! (total of 1,720)
#
# After sorting the neighborhoods based on their Mediterranean restaurants' average ratings, West Village has the highest average rating (9.30). Rockaway has the lowest average rating of 6.20 amongst other neighborhoods. There are some neighborhoods with no Mediterranean restaurant ratings such as Belmont!
#
# The Mediterranean restuarants in Manhattan have the highest average rating!

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, I would suggest the investors to open their new Persian restaurant in Manhattan and in Soho neighborhood! Although Soho has 5 other Mediterranean restaurant it seems that they all have a high rate of success! It seems that due to high demand, Manhattan has many restaurants and majority are successful! Based on the name of the restaurants, unfortunately I did not detect any Persian restaurants! Which might be a great news to the invetors since it shows there's a huge opportunity in opening a brand new Persian restaurant in the heart of Soho!
# I would also make sure I try out the Jack's Wife Freda next time in town!
# Finally, I would suggest a more thorough analysis using multiple location data sources! All the analysis in this report depend on the Foursquare data accuracy and limitations!
